# %% [markdown]
# Confronto dei risultati con una rete: 'Resnet18, pre-allenata

# %% [markdown]
# ### Dim. ultimo layer: (512, 16, 16)

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.models as models
from torchsummary import summary

# %%
'''
resnet18= models.resnet18(pretrained=True) 
features = nn.Sequential(*(list(resnet18.children())[0:8]))
features # 512, 16, 16
features.state_dict()
'''

# %%
resnet18= models.resnet18(pretrained=True) # .cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# ...

# %%
features = nn.Sequential(*(list(resnet18.children())[0:8]))
features

# %%
# fix weights
for param in features.parameters():
  param.requires_grad= False

# %%
# summary(resnet18, (3,512,512))
summary(features, (3,512,512))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 256, 256]           9,408
#        BatchNorm2d-2         [-1, 64, 256, 256]             128
#               ReLU-3         [-1, 64, 256, 256]               0
#          MaxPool2d-4         [-1, 64, 128, 128]               0
#             Conv2d-5         [-1, 64, 128, 128]          36,864
#        BatchNorm2d-6         [-1, 64, 128, 128]             128
# ...

# %%
features.state_dict()
# Out:
# OrderedDict([('0.weight',
#               tensor([[[[-1.0419e-02, -6.1356e-03, -1.8098e-03,  ...,  5.6615e-02,
#                           1.7083e-02, -1.2694e-02],
#                         [ 1.1083e-02,  9.5276e-03, -1.0993e-01,  ..., -2.7124e-01,
#                          -1.2907e-01,  3.7424e-03],
#                         [-6.9434e-03,  5.9089e-02,  2.9548e-01,  ...,  5.1972e-01,
#                           2.5632e-01,  6.3573e-02],
#                         ...,
#                         [-2.7535e-02,  1.6045e-02,  7.2595e-02,  ..., -3.3285e-01,
#                          -4.2058e-01, -2.5781e-01],
#                         [ 3.0613e-02,  4.0960e-02,  6.2850e-02,  ...,  4.1384e-01,
#                           3.9359e-01,  1.6606e-01],
#                         [-1.3736e-02, -3.6746e-03, -2.4084e-02,  ..., -1.5070e-01,
#                          -8.2230e-02, -5.7828e-03]],
#
#                        [[-1.1397e-02, -2.6619e-02, -3.4641e-02,  ...,  3.2521e-02,
# ...

# %%
torch.save(features, 'resnet_features.pth')

# %%
perc= 'resnet18_state-dict.pt'
torch.save(features.state_dict(), perc)

# %%
# prova
'''
Quando leggo il file '.pth' uso:
model.load_state_dict(torch.load('/content/drive/MyDrive/Computer Vision Project/Code/Retrieval/Checkpoints/ConvAutoencoder/clothes_conv_autoencoder_6ep.pt', 
                                 map_location=device)['model_state_dict'], strict=False)

posso provare a salvarlo con:
torch.save({'model_state_dict': model.state_dict()}, 'resnet_features.pth')

oppure:
model.load_state_dict(torch.load(file_name))
'''

# %% [markdown]
# Caricare nel notebook del retrieval i pesi salvati della RESNET18.

# %%
model = ConvAutoencoder().to(device)
model.load_state_dict(torch.load(PATH))
model.eval()

# %% [markdown]
# dim: (512, 16, 16) --> 131.072
