# %% [markdown]
# Dataset per la Triplet Loss

# %% [markdown]
# Creare il Dataframe (.csv) che contiene tutte le immagini (percorso) e le classi.

# %%
import os
import time
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
import numpy as np
import matplotlib.pyplot as plt

import pickle
import json

# %% [markdown]
# Considerando tutto il dataset.

# %%
path2= '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images'
dir= sorted(os.listdir(path2))

# %%
# sono 84
print('N° delle classi:',len(dir))
dir

# %%
#
dir[3] # 84 classi diverse
# Out:
# 'knitwear_track-tops'

# %%
# Dizionario di relazione tra classe e numeri
ass= dict()
for i in range(len(dir)):
  ass[i]= [dir[i]]
  
ass

# %%
with open('ass.json', 'w') as f:
  json.dump(ass, f)

# %%
# vado a fare una lista che contiene tutti i vari path
in_dir= []
for i in range(len(dir)):
  in_dir.append(os.path.join(path2, dir[i]+'/')) 

in_dir[3]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/knitwear_track-tops/'

# %%
in_dir_list= []
count_tot= 0
for i in range(len(in_dir)): # 84
  # numeri 
  in_dir_list.append(sorted(os.listdir(in_dir[i])))
  count_tot += len(in_dir_list[i])

count_tot # elementi totali, dentro ad in_dir_list e quindi nel dataset considerato (upper_body)
# Out:
# 30744

# %% [markdown]
# # N° volte da fare

# %%
# lunghezza n° elementi 
len(in_dir_list[0])
# Out:
# 124

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[0]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[0], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df0= pd.DataFrame() # nome del df
df0['image_path']= directory
df0['class']= dir[0] # valore della classe da inserire

df0
# Out:
#                                            image_path               class
# 0   /content/drive/MyDrive/Computer Vision Project...  denim_denim-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  denim_denim-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  denim_denim-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  denim_denim-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  denim_denim-shirts
# ..                                                ...                 ...
# 57  /content/drive/MyDrive/Computer Vision Project...  denim_denim-shirts
# 58  /content/drive/MyDrive/Computer Vision Project...  denim_denim-shirts
# 59  /content/drive/MyDrive/Computer Vision Project...  denim_denim-shirts
# 60  /content/drive/MyDrive/Computer Vision Project...  denim_denim-shirts
# 61  /content/drive/MyDrive/Computer Vision Project...  denim_denim-shirts
#
# [62 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df0.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/denim_denim-shirts/12141279ui_1_f.jpg'

# %%
# fine 0

# %%
# lunghezza n° elementi 
len(in_dir_list[1])
# Out:
# 6

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[1]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[1], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df1= pd.DataFrame() # nome del df
df1['image_path']= directory
df1['class']= dir[1] # valore della classe da inserire

df1
# Out:
#                                           image_path                         class
# 0  /content/drive/MyDrive/Computer Vision Project...  knitwear_knitted-polo-shirts
# 1  /content/drive/MyDrive/Computer Vision Project...  knitwear_knitted-polo-shirts
# 2  /content/drive/MyDrive/Computer Vision Project...  knitwear_knitted-polo-shirts

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 3
# contatore file non letti 3

# %%
# attenzione che siano tutte immagini

df1.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/knitwear_knitted-polo-shirts/39939482qw_1_r.jpg'

# %%
# fine 1

# %%
# lunghezza n° elementi 
len(in_dir_list[2])
# Out:
# 128

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[2]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[2], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df2= pd.DataFrame() # nome del df
df2['image_path']= directory
df2['class']= dir[2] # valore della classe da inserire

df2
# Out:
#                                            image_path                  class
# 0   /content/drive/MyDrive/Computer Vision Project...  knitwear_knitted-tops
# 1   /content/drive/MyDrive/Computer Vision Project...  knitwear_knitted-tops
# 2   /content/drive/MyDrive/Computer Vision Project...  knitwear_knitted-tops
# 3   /content/drive/MyDrive/Computer Vision Project...  knitwear_knitted-tops
# 4   /content/drive/MyDrive/Computer Vision Project...  knitwear_knitted-tops
# ..                                                ...                    ...
# 59  /content/drive/MyDrive/Computer Vision Project...  knitwear_knitted-tops
# 60  /content/drive/MyDrive/Computer Vision Project...  knitwear_knitted-tops
# 61  /content/drive/MyDrive/Computer Vision Project...  knitwear_knitted-tops
# 62  /content/drive/MyDrive/Computer Vision Project...  knitwear_knitted-tops
# 63  /content/drive/MyDrive/Computer Vision Project...  knitwear_knitted-tops
#
# [64 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 64
# contatore file non letti 64

# %%
# attenzione che siano tutte immagini

df2.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/knitwear_knitted-tops/12216132tw_1_r.jpg'

# %%
# fine 2

# %%
# lunghezza n° elementi 
len(in_dir_list[3])
# Out:
# 46

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[3]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[3], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df3= pd.DataFrame() # nome del df
df3['image_path']= directory
df3['class']= dir[3] # valore della classe da inserire

df3
# Out:
#                                            image_path                class
# 0   /content/drive/MyDrive/Computer Vision Project...  knitwear_track-tops
# 1   /content/drive/MyDrive/Computer Vision Project...  knitwear_track-tops
# 2   /content/drive/MyDrive/Computer Vision Project...  knitwear_track-tops
# 3   /content/drive/MyDrive/Computer Vision Project...  knitwear_track-tops
# 4   /content/drive/MyDrive/Computer Vision Project...  knitwear_track-tops
# 5   /content/drive/MyDrive/Computer Vision Project...  knitwear_track-tops
# 6   /content/drive/MyDrive/Computer Vision Project...  knitwear_track-tops
# 7   /content/drive/MyDrive/Computer Vision Project...  knitwear_track-tops
# 8   /content/drive/MyDrive/Computer Vision Project...  knitwear_track-tops
# 9   /content/drive/MyDrive/Computer Vision Project...  knitwear_track-tops
# 10  /content/drive/MyDrive/Computer Vision Project...  knitwear_track-tops
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 23
# contatore file non letti 23

# %%
# attenzione che siano tutte immagini

df3.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/knitwear_track-tops/46614972ah_1_r.jpg'

# %%
# fine 3

# %%
# lunghezza n° elementi 
len(in_dir_list[4])
# Out:
# 2

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[4]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[4], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df4= pd.DataFrame() # nome del df
df4['image_path']= directory
df4['class']= dir[4] # valore della classe da inserire

df4
# Out:
#                                           image_path                 class
# 0  /content/drive/MyDrive/Computer Vision Project...  leather_leather-tops

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 1
# contatore file non letti 1

# %%
# attenzione che siano tutte immagini

df4.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/leather_leather-tops/59142098cf_1_d.jpg'

# %%
# fine 4

# %%
# lunghezza n° elementi 
len(in_dir_list[5])
# Out:
# 20

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[5]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[5], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df5= pd.DataFrame() # nome del df
df5['image_path']= directory
df5['class']= dir[5] # valore della classe da inserire

df5
# Out:
#                                           image_path                           class
# 0  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_long-sleeves-polos
# 1  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_long-sleeves-polos
# 2  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_long-sleeves-polos
# 3  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_long-sleeves-polos
# 4  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_long-sleeves-polos
# 5  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_long-sleeves-polos
# 6  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_long-sleeves-polos
# 7  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_long-sleeves-polos
# 8  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_long-sleeves-polos
# 9  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_long-sleeves-polos

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 10
# contatore file non letti 10

# %%
# attenzione che siano tutte immagini

df5.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/polo-shirts_long-sleeves-polos/46566106dj_1_r.jpg'

# %%
# fine 5

# %%
# lunghezza n° elementi 
len(in_dir_list[6])
# Out:
# 434

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[6]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[6], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df6= pd.DataFrame() # nome del df
df6['image_path']= directory
df6['class']= dir[6] # valore della classe da inserire

df6
# Out:
#                                             image_path                            class
# 0    /content/drive/MyDrive/Computer Vision Project...  polo-shirts_short-sleeves-polos
# 1    /content/drive/MyDrive/Computer Vision Project...  polo-shirts_short-sleeves-polos
# 2    /content/drive/MyDrive/Computer Vision Project...  polo-shirts_short-sleeves-polos
# 3    /content/drive/MyDrive/Computer Vision Project...  polo-shirts_short-sleeves-polos
# 4    /content/drive/MyDrive/Computer Vision Project...  polo-shirts_short-sleeves-polos
# ..                                                 ...                              ...
# 212  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_short-sleeves-polos
# 213  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_short-sleeves-polos
# 214  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_short-sleeves-polos
# 215  /content/drive/MyDrive/Computer Vision Project...  polo-shirts_short-sleeves-polos
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 217
# contatore file non letti 217

# %%
# attenzione che siano tutte immagini

df6.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/polo-shirts_short-sleeves-polos/46501912mb_1_r.jpg'

# %%
# fine 6

# %%
# lunghezza n° elementi 
len(in_dir_list[7])
# Out:
# 12

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[7]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[7], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df7= pd.DataFrame() # nome del df
df7['image_path']= directory
df7['class']= dir[7] # valore della classe da inserire

df7
# Out:
#                                           image_path                         class
# 0  /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knit-sweater
# 1  /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knit-sweater
# 2  /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knit-sweater
# 3  /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knit-sweater
# 4  /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knit-sweater
# 5  /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knit-sweater

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 6
# contatore file non letti 6

# %%
# attenzione che siano tutte immagini

df7.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts-and-tops_knit-sweater/37493954kk_1_d.jpg'

# %%
# fine 7

# %%
# lunghezza n° elementi 
len(in_dir_list[8])
# Out:
# 98

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[8]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[8], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df8= pd.DataFrame() # nome del df
df8['image_path']= directory
df8['class']= dir[8] # valore della classe da inserire

df8
# Out:
#                                            image_path                                     class
# 0   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knitwear-shirts-and-tops
# 1   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knitwear-shirts-and-tops
# 2   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knitwear-shirts-and-tops
# 3   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knitwear-shirts-and-tops
# 4   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knitwear-shirts-and-tops
# 5   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knitwear-shirts-and-tops
# 6   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knitwear-shirts-and-tops
# 7   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knitwear-shirts-and-tops
# 8   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_knitwear-shirts-and-tops
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 49
# contatore file non letti 49

# %%
# attenzione che siano tutte immagini

df8.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts-and-tops_knitwear-shirts-and-tops/34225999jg_1_f.jpg'

# %%
# fine 8

# %%
# lunghezza n° elementi 
len(in_dir_list[9])
# Out:
# 186

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[9]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[9], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df9= pd.DataFrame() # nome del df
df9['image_path']= directory
df9['class']= dir[9] # valore della classe da inserire

df9
# Out:
#                                            image_path                               class
# 0   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_shirts-and-blouses
# 1   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_shirts-and-blouses
# 2   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_shirts-and-blouses
# 3   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_shirts-and-blouses
# 4   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_shirts-and-blouses
# ..                                                ...                                 ...
# 88  /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_shirts-and-blouses
# 89  /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_shirts-and-blouses
# 90  /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_shirts-and-blouses
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 93
# contatore file non letti 93

# %%
# attenzione che siano tutte immagini

df9.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts-and-tops_shirts-and-blouses/12035359dc_1_f.jpg'

# %%
# fine 9

# %%
# lunghezza n° elementi 
len(in_dir_list[10])
# Out:
# 96

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[10]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[10], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df10= pd.DataFrame() # nome del df
df10['image_path']= directory
df10['class']= dir[10] # valore della classe da inserire

df10
# Out:
#                                            image_path                 class
# 0   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_tops
# 1   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_tops
# 2   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_tops
# 3   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_tops
# 4   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_tops
# 5   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_tops
# 6   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_tops
# 7   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_tops
# 8   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_tops
# 9   /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_tops
# 10  /content/drive/MyDrive/Computer Vision Project...  shirts-and-tops_tops
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 48
# contatore file non letti 48

# %%
# attenzione che siano tutte immagini

df10.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts-and-tops_tops/12021692fw_1_f.jpg'

# %%
# fine 10

# %%
# lunghezza n° elementi 
len(in_dir_list[11])
# Out:
# 3276

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[11]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[11], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df11= pd.DataFrame() # nome del df
df11['image_path']= directory
df11['class']= dir[11] # valore della classe da inserire

df11
# Out:
#                                              image_path           class
# 0     /content/drive/MyDrive/Computer Vision Project...  shirts_blouses
# 1     /content/drive/MyDrive/Computer Vision Project...  shirts_blouses
# 2     /content/drive/MyDrive/Computer Vision Project...  shirts_blouses
# 3     /content/drive/MyDrive/Computer Vision Project...  shirts_blouses
# 4     /content/drive/MyDrive/Computer Vision Project...  shirts_blouses
# ...                                                 ...             ...
# 1633  /content/drive/MyDrive/Computer Vision Project...  shirts_blouses
# 1634  /content/drive/MyDrive/Computer Vision Project...  shirts_blouses
# 1635  /content/drive/MyDrive/Computer Vision Project...  shirts_blouses
# 1636  /content/drive/MyDrive/Computer Vision Project...  shirts_blouses
# 1637  /content/drive/MyDrive/Computer Vision Project...  shirts_blouses
#
# [1638 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 1638
# contatore file non letti 1638

# %%
# attenzione che siano tutte immagini

df11.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_blouses/11619237ej_1_f.jpg'

# %%
# fine 11

# %%
# lunghezza n° elementi 
len(in_dir_list[12])
# Out:
# 330

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[12]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[12], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df12= pd.DataFrame() # nome del df
df12['image_path']= directory
df12['class']= dir[12] # valore della classe da inserire

df12
# Out:
#                                             image_path                 class
# 0    /content/drive/MyDrive/Computer Vision Project...  shirts_casual-shirts
# 1    /content/drive/MyDrive/Computer Vision Project...  shirts_casual-shirts
# 2    /content/drive/MyDrive/Computer Vision Project...  shirts_casual-shirts
# 3    /content/drive/MyDrive/Computer Vision Project...  shirts_casual-shirts
# 4    /content/drive/MyDrive/Computer Vision Project...  shirts_casual-shirts
# ..                                                 ...                   ...
# 160  /content/drive/MyDrive/Computer Vision Project...  shirts_casual-shirts
# 161  /content/drive/MyDrive/Computer Vision Project...  shirts_casual-shirts
# 162  /content/drive/MyDrive/Computer Vision Project...  shirts_casual-shirts
# 163  /content/drive/MyDrive/Computer Vision Project...  shirts_casual-shirts
# 164  /content/drive/MyDrive/Computer Vision Project...  shirts_casual-shirts
#
# [165 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 165
# contatore file non letti 165

# %%
# attenzione che siano tutte immagini

df12.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_casual-shirts/12158120bp_1_r.jpg'

# %%
# fine 12

# %%
# lunghezza n° elementi 
len(in_dir_list[13])
# Out:
# 36

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[13]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[13], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df13= pd.DataFrame() # nome del df
df13['image_path']= directory
df13['class']= dir[13] # valore della classe da inserire

df13
# Out:
#                                            image_path                  class
# 0   /content/drive/MyDrive/Computer Vision Project...  shirts_checked-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  shirts_checked-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  shirts_checked-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  shirts_checked-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  shirts_checked-shirts
# 5   /content/drive/MyDrive/Computer Vision Project...  shirts_checked-shirts
# 6   /content/drive/MyDrive/Computer Vision Project...  shirts_checked-shirts
# 7   /content/drive/MyDrive/Computer Vision Project...  shirts_checked-shirts
# 8   /content/drive/MyDrive/Computer Vision Project...  shirts_checked-shirts
# 9   /content/drive/MyDrive/Computer Vision Project...  shirts_checked-shirts
# 10  /content/drive/MyDrive/Computer Vision Project...  shirts_checked-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 18
# contatore file non letti 18

# %%
# attenzione che siano tutte immagini

df13.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_checked-shirts/46600427mo_1_r.jpg'

# %%
# fine 13

# %%
# lunghezza n° elementi 
len(in_dir_list[14])
# Out:
# 34

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[14]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[14], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df14= pd.DataFrame() # nome del df
df14['image_path']= directory
df14['class']= dir[14] # valore della classe da inserire

df14
# Out:
#                                            image_path                  class
# 0   /content/drive/MyDrive/Computer Vision Project...  shirts_classic-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  shirts_classic-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  shirts_classic-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  shirts_classic-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  shirts_classic-shirts
# 5   /content/drive/MyDrive/Computer Vision Project...  shirts_classic-shirts
# 6   /content/drive/MyDrive/Computer Vision Project...  shirts_classic-shirts
# 7   /content/drive/MyDrive/Computer Vision Project...  shirts_classic-shirts
# 8   /content/drive/MyDrive/Computer Vision Project...  shirts_classic-shirts
# 9   /content/drive/MyDrive/Computer Vision Project...  shirts_classic-shirts
# 10  /content/drive/MyDrive/Computer Vision Project...  shirts_classic-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 17
# contatore file non letti 17

# %%
# attenzione che siano tutte immagini

df14.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_classic-shirts/35380801bv_1_r.jpg'

# %%
# fine 14

# %%
# lunghezza n° elementi 
len(in_dir_list[15])
# Out:
# 34

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[15]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[15], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df15= pd.DataFrame() # nome del df
df15['image_path']= directory
df15['class']= dir[15] # valore della classe da inserire

df15
# Out:
#                                            image_path                class
# 0   /content/drive/MyDrive/Computer Vision Project...  shirts_denim-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  shirts_denim-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  shirts_denim-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  shirts_denim-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  shirts_denim-shirts
# 5   /content/drive/MyDrive/Computer Vision Project...  shirts_denim-shirts
# 6   /content/drive/MyDrive/Computer Vision Project...  shirts_denim-shirts
# 7   /content/drive/MyDrive/Computer Vision Project...  shirts_denim-shirts
# 8   /content/drive/MyDrive/Computer Vision Project...  shirts_denim-shirts
# 9   /content/drive/MyDrive/Computer Vision Project...  shirts_denim-shirts
# 10  /content/drive/MyDrive/Computer Vision Project...  shirts_denim-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 17
# contatore file non letti 17

# %%
# attenzione che siano tutte immagini

df15.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_denim-shirts/38264803ak_1_f.jpg'

# %%
# fine 15

# %%
# lunghezza n° elementi 
len(in_dir_list[16])
# Out:
# 4

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[16]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[16], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df16= pd.DataFrame() # nome del df
df16['image_path']= directory
df16['class']= dir[16] # valore della classe da inserire

df16
# Out:
#                                           image_path                 class
# 0  /content/drive/MyDrive/Computer Vision Project...  shirts_formal-shirts
# 1  /content/drive/MyDrive/Computer Vision Project...  shirts_formal-shirts

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df16.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_formal-shirts/38857987eh_1_d.jpg'

# %%
# fine 16

# %%
# lunghezza n° elementi 
len(in_dir_list[17])
# Out:
# 10

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[17]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[17], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df17= pd.DataFrame() # nome del df
df17['image_path']= directory
df17['class']= dir[17] # valore della classe da inserire

df17
# Out:
#                                           image_path           class
# 0  /content/drive/MyDrive/Computer Vision Project...  shirts_kaftans
# 1  /content/drive/MyDrive/Computer Vision Project...  shirts_kaftans
# 2  /content/drive/MyDrive/Computer Vision Project...  shirts_kaftans
# 3  /content/drive/MyDrive/Computer Vision Project...  shirts_kaftans
# 4  /content/drive/MyDrive/Computer Vision Project...  shirts_kaftans

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df17.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_kaftans/38709327jw_1_f.jpg'

# %%
# fine 17

# %%
# lunghezza n° elementi 
len(in_dir_list[18])
# Out:
# 376

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[18]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[18], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df18= pd.DataFrame() # nome del df
df18['image_path']= directory
df18['class']= dir[18] # valore della classe da inserire

df18
# Out:
#                                             image_path                      class
# 0    /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeve-shirts
# 1    /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeve-shirts
# 2    /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeve-shirts
# 3    /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeve-shirts
# 4    /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeve-shirts
# ..                                                 ...                        ...
# 183  /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeve-shirts
# 184  /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeve-shirts
# 185  /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeve-shirts
# 186  /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeve-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 188
# contatore file non letti 188

# %%
# attenzione che siano tutte immagini

df18.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_long-sleeve-shirts/12384716oo_1_f.jpg'

# %%
# fine 18

# %%
# lunghezza n° elementi 
len(in_dir_list[19])
# Out:
# 110

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[19]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[19], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df19= pd.DataFrame() # nome del df
df19['image_path']= directory
df19['class']= dir[19] # valore della classe da inserire

df19
# Out:
#                                            image_path                       class
# 0   /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeved-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeved-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeved-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeved-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeved-shirts
# 5   /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeved-shirts
# 6   /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeved-shirts
# 7   /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeved-shirts
# 8   /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeved-shirts
# 9   /content/drive/MyDrive/Computer Vision Project...  shirts_long-sleeved-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 55
# contatore file non letti 55

# %%
# attenzione che siano tutte immagini

df19.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_long-sleeved-shirts/46554902sd_1_r.jpg'

# %%
# fine 19

# %%
# lunghezza n° elementi 
len(in_dir_list[20])
# Out:
# 34

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[20]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[20], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df20= pd.DataFrame() # nome del df
df20['image_path']= directory
df20['class']= dir[20] # valore della classe da inserire

df20
# Out:
#                                            image_path              class
# 0   /content/drive/MyDrive/Computer Vision Project...  shirts_men-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  shirts_men-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  shirts_men-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  shirts_men-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  shirts_men-shirts
# 5   /content/drive/MyDrive/Computer Vision Project...  shirts_men-shirts
# 6   /content/drive/MyDrive/Computer Vision Project...  shirts_men-shirts
# 7   /content/drive/MyDrive/Computer Vision Project...  shirts_men-shirts
# 8   /content/drive/MyDrive/Computer Vision Project...  shirts_men-shirts
# 9   /content/drive/MyDrive/Computer Vision Project...  shirts_men-shirts
# 10  /content/drive/MyDrive/Computer Vision Project...  shirts_men-shirts
# 11  /content/drive/MyDrive/Computer Vision Project...  shirts_men-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 17
# contatore file non letti 17

# %%
# attenzione che siano tutte immagini

df20.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_men-shirts/38601931qg_1_f.jpg'

# %%
# fine 20

# %%
# lunghezza n° elementi 
len(in_dir_list[21])
# Out:
# 134

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[21]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[21], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df21= pd.DataFrame() # nome del df
df21['image_path']= directory
df21['class']= dir[21] # valore della classe da inserire

df21
# Out:
#                                            image_path                class
# 0   /content/drive/MyDrive/Computer Vision Project...  shirts_plain-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  shirts_plain-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  shirts_plain-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  shirts_plain-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  shirts_plain-shirts
# ..                                                ...                  ...
# 62  /content/drive/MyDrive/Computer Vision Project...  shirts_plain-shirts
# 63  /content/drive/MyDrive/Computer Vision Project...  shirts_plain-shirts
# 64  /content/drive/MyDrive/Computer Vision Project...  shirts_plain-shirts
# 65  /content/drive/MyDrive/Computer Vision Project...  shirts_plain-shirts
# 66  /content/drive/MyDrive/Computer Vision Project...  shirts_plain-shirts
#
# [67 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 67
# contatore file non letti 67

# %%
# attenzione che siano tutte immagini

df21.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_plain-shirts/46554913ib_1_r.jpg'

# %%
# fine 21

# %%
# lunghezza n° elementi 
len(in_dir_list[22])
# Out:
# 160

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[22]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[22], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df22= pd.DataFrame() # nome del df
df22['image_path']= directory
df22['class']= dir[22] # valore della classe da inserire

df22
# Out:
#                                            image_path                  class
# 0   /content/drive/MyDrive/Computer Vision Project...  shirts_printed-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  shirts_printed-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  shirts_printed-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  shirts_printed-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  shirts_printed-shirts
# ..                                                ...                    ...
# 75  /content/drive/MyDrive/Computer Vision Project...  shirts_printed-shirts
# 76  /content/drive/MyDrive/Computer Vision Project...  shirts_printed-shirts
# 77  /content/drive/MyDrive/Computer Vision Project...  shirts_printed-shirts
# 78  /content/drive/MyDrive/Computer Vision Project...  shirts_printed-shirts
# 79  /content/drive/MyDrive/Computer Vision Project...  shirts_printed-shirts
#
# [80 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df22.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_printed-shirts/46556747ob_1_r.jpg'

# %%
# fine 22

# %%
# lunghezza n° elementi 
len(in_dir_list[23])
# Out:
# 2004

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[23]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[23], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df23= pd.DataFrame() # nome del df
df23['image_path']= directory
df23['class']= dir[23] # valore della classe da inserire

df23
# Out:
#                                              image_path          class
# 0     /content/drive/MyDrive/Computer Vision Project...  shirts_shirts
# 1     /content/drive/MyDrive/Computer Vision Project...  shirts_shirts
# 2     /content/drive/MyDrive/Computer Vision Project...  shirts_shirts
# 3     /content/drive/MyDrive/Computer Vision Project...  shirts_shirts
# 4     /content/drive/MyDrive/Computer Vision Project...  shirts_shirts
# ...                                                 ...            ...
# 997   /content/drive/MyDrive/Computer Vision Project...  shirts_shirts
# 998   /content/drive/MyDrive/Computer Vision Project...  shirts_shirts
# 999   /content/drive/MyDrive/Computer Vision Project...  shirts_shirts
# 1000  /content/drive/MyDrive/Computer Vision Project...  shirts_shirts
# 1001  /content/drive/MyDrive/Computer Vision Project...  shirts_shirts
#
# [1002 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 1002
# contatore file non letti 1002

# %%
# attenzione che siano tutte immagini

df23.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_shirts/12005650jl_1_f.jpg'

# %%
# fine 23

# %%
# lunghezza n° elementi 
len(in_dir_list[24])
# Out:
# 40

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[24]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[24], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df24= pd.DataFrame() # nome del df
df24['image_path']= directory
df24['class']= dir[24] # valore della classe da inserire

df24
# Out:
#                                            image_path                       class
# 0   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeve-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeve-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeve-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeve-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeve-shirts
# 5   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeve-shirts
# 6   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeve-shirts
# 7   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeve-shirts
# 8   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeve-shirts
# 9   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeve-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 20
# contatore file non letti 20

# %%
# attenzione che siano tutte immagini

df24.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_short-sleeve-shirts/38264781ro_1_f.jpg'

# %%
# fine 24

# %%
# lunghezza n° elementi 
len(in_dir_list[25])
# Out:
# 64

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[25]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[25], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df25= pd.DataFrame() # nome del df
df25['image_path']= directory
df25['class']= dir[25] # valore della classe da inserire

df25
# Out:
#                                            image_path                        class
# 0   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeved-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeved-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeved-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeved-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeved-shirts
# 5   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeved-shirts
# 6   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeved-shirts
# 7   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeved-shirts
# 8   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeved-shirts
# 9   /content/drive/MyDrive/Computer Vision Project...  shirts_short-sleeved-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 32
# contatore file non letti 32

# %%
# attenzione che siano tutte immagini

df25.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_short-sleeved-shirts/46554915wo_1_r.jpg'

# %%
# fine 25

# %%
# lunghezza n° elementi 
len(in_dir_list[26])
# Out:
# 20

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[26]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[26], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df26= pd.DataFrame() # nome del df
df26['image_path']= directory
df26['class']= dir[26] # valore della classe da inserire

df26
# Out:
#                                           image_path                 class
# 0  /content/drive/MyDrive/Computer Vision Project...  shirts_sl-woven-tops
# 1  /content/drive/MyDrive/Computer Vision Project...  shirts_sl-woven-tops
# 2  /content/drive/MyDrive/Computer Vision Project...  shirts_sl-woven-tops
# 3  /content/drive/MyDrive/Computer Vision Project...  shirts_sl-woven-tops
# 4  /content/drive/MyDrive/Computer Vision Project...  shirts_sl-woven-tops
# 5  /content/drive/MyDrive/Computer Vision Project...  shirts_sl-woven-tops
# 6  /content/drive/MyDrive/Computer Vision Project...  shirts_sl-woven-tops
# 7  /content/drive/MyDrive/Computer Vision Project...  shirts_sl-woven-tops
# 8  /content/drive/MyDrive/Computer Vision Project...  shirts_sl-woven-tops
# 9  /content/drive/MyDrive/Computer Vision Project...  shirts_sl-woven-tops

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 10
# contatore file non letti 10

# %%
# attenzione che siano tutte immagini

df26.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_sl-woven-tops/46556607eg_1_r.jpg'

# %%
# fine 26

# %%
# lunghezza n° elementi 
len(in_dir_list[27])
# Out:
# 10

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[27]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[27], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df27= pd.DataFrame() # nome del df
df27['image_path']= directory
df27['class']= dir[27] # valore della classe da inserire

df27
# Out:
#                                           image_path                     class
# 0  /content/drive/MyDrive/Computer Vision Project...  shirts_sleeveless-shirts
# 1  /content/drive/MyDrive/Computer Vision Project...  shirts_sleeveless-shirts
# 2  /content/drive/MyDrive/Computer Vision Project...  shirts_sleeveless-shirts
# 3  /content/drive/MyDrive/Computer Vision Project...  shirts_sleeveless-shirts
# 4  /content/drive/MyDrive/Computer Vision Project...  shirts_sleeveless-shirts

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df27.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_sleeveless-shirts/38798663pj_1_f.jpg'

# %%
# fine 27

# %%
# lunghezza n° elementi 
len(in_dir_list[28])
# Out:
# 18

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[28]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[28], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df28= pd.DataFrame() # nome del df
df28['image_path']= directory
df28['class']= dir[28] # valore della classe da inserire

df28
# Out:
#                                           image_path                 class
# 0  /content/drive/MyDrive/Computer Vision Project...  shirts_ss-woven-tops
# 1  /content/drive/MyDrive/Computer Vision Project...  shirts_ss-woven-tops
# 2  /content/drive/MyDrive/Computer Vision Project...  shirts_ss-woven-tops
# 3  /content/drive/MyDrive/Computer Vision Project...  shirts_ss-woven-tops
# 4  /content/drive/MyDrive/Computer Vision Project...  shirts_ss-woven-tops
# 5  /content/drive/MyDrive/Computer Vision Project...  shirts_ss-woven-tops
# 6  /content/drive/MyDrive/Computer Vision Project...  shirts_ss-woven-tops
# 7  /content/drive/MyDrive/Computer Vision Project...  shirts_ss-woven-tops
# 8  /content/drive/MyDrive/Computer Vision Project...  shirts_ss-woven-tops

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 9
# contatore file non letti 9

# %%
# attenzione che siano tutte immagini

df28.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_ss-woven-tops/46557094ke_1_r.jpg'

# %%
# fine 28

# %%
# lunghezza n° elementi 
len(in_dir_list[29])
# Out:
# 54

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[29]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[29], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df29= pd.DataFrame() # nome del df
df29['image_path']= directory
df29['class']= dir[29] # valore della classe da inserire

df29
# Out:
#                                            image_path                  class
# 0   /content/drive/MyDrive/Computer Vision Project...  shirts_striped-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  shirts_striped-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  shirts_striped-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  shirts_striped-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  shirts_striped-shirts
# 5   /content/drive/MyDrive/Computer Vision Project...  shirts_striped-shirts
# 6   /content/drive/MyDrive/Computer Vision Project...  shirts_striped-shirts
# 7   /content/drive/MyDrive/Computer Vision Project...  shirts_striped-shirts
# 8   /content/drive/MyDrive/Computer Vision Project...  shirts_striped-shirts
# 9   /content/drive/MyDrive/Computer Vision Project...  shirts_striped-shirts
# 10  /content/drive/MyDrive/Computer Vision Project...  shirts_striped-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df29.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_striped-shirts/46564747qp_1_r.jpg'

# %%
# fine 29

# %%
# lunghezza n° elementi 
len(in_dir_list[30])
# Out:
# 258

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[30]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[30], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df30= pd.DataFrame() # nome del df
df30['image_path']= directory
df30['class']= dir[30] # valore della classe da inserire

df30
# Out:
#                                             image_path        class
# 0    /content/drive/MyDrive/Computer Vision Project...  shirts_tops
# 1    /content/drive/MyDrive/Computer Vision Project...  shirts_tops
# 2    /content/drive/MyDrive/Computer Vision Project...  shirts_tops
# 3    /content/drive/MyDrive/Computer Vision Project...  shirts_tops
# 4    /content/drive/MyDrive/Computer Vision Project...  shirts_tops
# ..                                                 ...          ...
# 124  /content/drive/MyDrive/Computer Vision Project...  shirts_tops
# 125  /content/drive/MyDrive/Computer Vision Project...  shirts_tops
# 126  /content/drive/MyDrive/Computer Vision Project...  shirts_tops
# 127  /content/drive/MyDrive/Computer Vision Project...  shirts_tops
# 128  /content/drive/MyDrive/Computer Vision Project...  shirts_tops
#
# [129 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 129
# contatore file non letti 129

# %%
# attenzione che siano tutte immagini

df30.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_tops/12088744ss_1_r.jpg'

# %%
# fine 30

# %%
# lunghezza n° elementi 
len(in_dir_list[31])
# Out:
# 10

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[31]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[31], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df31= pd.DataFrame() # nome del df
df31['image_path']= directory
df31['class']= dir[31] # valore della classe da inserire

df31
# Out:
#                                           image_path          class
# 0  /content/drive/MyDrive/Computer Vision Project...  shirts_tunics
# 1  /content/drive/MyDrive/Computer Vision Project...  shirts_tunics
# 2  /content/drive/MyDrive/Computer Vision Project...  shirts_tunics
# 3  /content/drive/MyDrive/Computer Vision Project...  shirts_tunics
# 4  /content/drive/MyDrive/Computer Vision Project...  shirts_tunics

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df31.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/shirts_tunics/37247338ao_1_f.jpg'

# %%
# fine 31

# %%
# lunghezza n° elementi 
len(in_dir_list[32])
# Out:
# 72

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[32]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[32], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df32= pd.DataFrame() # nome del df
df32['image_path']= directory
df32['class']= dir[32] # valore della classe da inserire

df32
# Out:
#                                            image_path                 class
# 0   /content/drive/MyDrive/Computer Vision Project...  t-shirts_active-tops
# 1   /content/drive/MyDrive/Computer Vision Project...  t-shirts_active-tops
# 2   /content/drive/MyDrive/Computer Vision Project...  t-shirts_active-tops
# 3   /content/drive/MyDrive/Computer Vision Project...  t-shirts_active-tops
# 4   /content/drive/MyDrive/Computer Vision Project...  t-shirts_active-tops
# 5   /content/drive/MyDrive/Computer Vision Project...  t-shirts_active-tops
# 6   /content/drive/MyDrive/Computer Vision Project...  t-shirts_active-tops
# 7   /content/drive/MyDrive/Computer Vision Project...  t-shirts_active-tops
# 8   /content/drive/MyDrive/Computer Vision Project...  t-shirts_active-tops
# 9   /content/drive/MyDrive/Computer Vision Project...  t-shirts_active-tops
# 10  /content/drive/MyDrive/Computer Vision Project...  t-shirts_active-tops
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 36
# contatore file non letti 36

# %%
# attenzione che siano tutte immagini

df32.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/t-shirts_active-tops/12075525xx_1_r.jpg'

# %%
# fine 32

# %%
# lunghezza n° elementi 
len(in_dir_list[33])
# Out:
# 568

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[33]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[33], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df33= pd.DataFrame() # nome del df
df33['image_path']= directory
df33['class']= dir[33] # valore della classe da inserire

df33
# Out:
#                                             image_path                      class
# 0    /content/drive/MyDrive/Computer Vision Project...  t-shirts_graphic-t-shirts
# 1    /content/drive/MyDrive/Computer Vision Project...  t-shirts_graphic-t-shirts
# 2    /content/drive/MyDrive/Computer Vision Project...  t-shirts_graphic-t-shirts
# 3    /content/drive/MyDrive/Computer Vision Project...  t-shirts_graphic-t-shirts
# 4    /content/drive/MyDrive/Computer Vision Project...  t-shirts_graphic-t-shirts
# ..                                                 ...                        ...
# 279  /content/drive/MyDrive/Computer Vision Project...  t-shirts_graphic-t-shirts
# 280  /content/drive/MyDrive/Computer Vision Project...  t-shirts_graphic-t-shirts
# 281  /content/drive/MyDrive/Computer Vision Project...  t-shirts_graphic-t-shirts
# 282  /content/drive/MyDrive/Computer Vision Project...  t-shirts_graphic-t-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 284
# contatore file non letti 284

# %%
# attenzione che siano tutte immagini

df33.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/t-shirts_graphic-t-shirts/46556670qp_1_r.jpg'

# %%
# fine 33

# %%
# lunghezza n° elementi 
len(in_dir_list[34])
# Out:
# 1830

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[34]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[34], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df34= pd.DataFrame() # nome del df
df34['image_path']= directory
df34['class']= dir[34] # valore della classe da inserire

df34
# Out:
#                                             image_path                   class
# 0    /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-t-shirts
# 1    /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-t-shirts
# 2    /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-t-shirts
# 3    /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-t-shirts
# 4    /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-t-shirts
# ..                                                 ...                     ...
# 910  /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-t-shirts
# 911  /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-t-shirts
# 912  /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-t-shirts
# 913  /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-t-shirts
# 914  /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-t-shirts
#
# [915 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 915
# contatore file non letti 915

# %%
# attenzione che siano tutte immagini

df34.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/t-shirts_logo-t-shirts/12208020ou_1_r.jpg'

# %%
# fine 34

# %%
# lunghezza n° elementi 
len(in_dir_list[35])
# Out:
# 12

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[35]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[35], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df35= pd.DataFrame() # nome del df
df35['image_path']= directory
df35['class']= dir[35] # valore della classe da inserire

df35
# Out:
#                                           image_path                    class
# 0  /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-tank-tops
# 1  /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-tank-tops
# 2  /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-tank-tops
# 3  /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-tank-tops
# 4  /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-tank-tops
# 5  /content/drive/MyDrive/Computer Vision Project...  t-shirts_logo-tank-tops

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df35.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/t-shirts_logo-tank-tops/46564686mn_1_r.jpg'

# %%
# fine 35

# %%
# lunghezza n° elementi 
len(in_dir_list[36])
# Out:
# 34

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[36]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[36], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df36= pd.DataFrame() # nome del df
df36['image_path']= directory
df36['class']= dir[36] # valore della classe da inserire

df36
# Out:
#                                            image_path                  class
# 0   /content/drive/MyDrive/Computer Vision Project...  t-shirts_men-t-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  t-shirts_men-t-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  t-shirts_men-t-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  t-shirts_men-t-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  t-shirts_men-t-shirts
# 5   /content/drive/MyDrive/Computer Vision Project...  t-shirts_men-t-shirts
# 6   /content/drive/MyDrive/Computer Vision Project...  t-shirts_men-t-shirts
# 7   /content/drive/MyDrive/Computer Vision Project...  t-shirts_men-t-shirts
# 8   /content/drive/MyDrive/Computer Vision Project...  t-shirts_men-t-shirts
# 9   /content/drive/MyDrive/Computer Vision Project...  t-shirts_men-t-shirts
# 10  /content/drive/MyDrive/Computer Vision Project...  t-shirts_men-t-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 17
# contatore file non letti 17

# %%
# attenzione che siano tutte immagini

df36.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/t-shirts_men-t-shirts/12048935mj_1_f.jpg'

# %%
# fine 36

# %%
# lunghezza n° elementi 
len(in_dir_list[37])
# Out:
# 72

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[37]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[37], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df37= pd.DataFrame() # nome del df
df37['image_path']= directory
df37['class']= dir[37] # valore della classe da inserire

df37
# Out:
#                                            image_path                   class
# 0   /content/drive/MyDrive/Computer Vision Project...  t-shirts_non-logo-tees
# 1   /content/drive/MyDrive/Computer Vision Project...  t-shirts_non-logo-tees
# 2   /content/drive/MyDrive/Computer Vision Project...  t-shirts_non-logo-tees
# 3   /content/drive/MyDrive/Computer Vision Project...  t-shirts_non-logo-tees
# 4   /content/drive/MyDrive/Computer Vision Project...  t-shirts_non-logo-tees
# 5   /content/drive/MyDrive/Computer Vision Project...  t-shirts_non-logo-tees
# 6   /content/drive/MyDrive/Computer Vision Project...  t-shirts_non-logo-tees
# 7   /content/drive/MyDrive/Computer Vision Project...  t-shirts_non-logo-tees
# 8   /content/drive/MyDrive/Computer Vision Project...  t-shirts_non-logo-tees
# 9   /content/drive/MyDrive/Computer Vision Project...  t-shirts_non-logo-tees
# 10  /content/drive/MyDrive/Computer Vision Project...  t-shirts_non-logo-tees
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 36
# contatore file non letti 36

# %%
# attenzione che siano tutte immagini

df37.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/t-shirts_non-logo-tees/46567134ua_1_r.jpg'

# %%
# fine 37

# %%
# lunghezza n° elementi 
len(in_dir_list[38])
# Out:
# 338

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[38]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[38], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df38= pd.DataFrame() # nome del df
df38['image_path']= directory
df38['class']= dir[38] # valore della classe da inserire

df38
# Out:
#                                             image_path                 class
# 0    /content/drive/MyDrive/Computer Vision Project...  t-shirts_polo-shirts
# 1    /content/drive/MyDrive/Computer Vision Project...  t-shirts_polo-shirts
# 2    /content/drive/MyDrive/Computer Vision Project...  t-shirts_polo-shirts
# 3    /content/drive/MyDrive/Computer Vision Project...  t-shirts_polo-shirts
# 4    /content/drive/MyDrive/Computer Vision Project...  t-shirts_polo-shirts
# ..                                                 ...                   ...
# 164  /content/drive/MyDrive/Computer Vision Project...  t-shirts_polo-shirts
# 165  /content/drive/MyDrive/Computer Vision Project...  t-shirts_polo-shirts
# 166  /content/drive/MyDrive/Computer Vision Project...  t-shirts_polo-shirts
# 167  /content/drive/MyDrive/Computer Vision Project...  t-shirts_polo-shirts
# 168  /content/drive/MyDrive/Computer Vision Project...  t-shirts_polo-shirts
#
# [169 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 169
# contatore file non letti 169

# %%
# attenzione che siano tutte immagini

df38.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/t-shirts_polo-shirts/12059623rm_1_r.jpg'

# %%
# fine 38

# %%
# lunghezza n° elementi 
len(in_dir_list[39])
# Out:
# 8

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[39]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[39], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df39= pd.DataFrame() # nome del df
df39['image_path']= directory
df39['class']= dir[39] # valore della classe da inserire

df39
# Out:
#                                           image_path                        class
# 0  /content/drive/MyDrive/Computer Vision Project...  t-shirts_short-sleeved-tees
# 1  /content/drive/MyDrive/Computer Vision Project...  t-shirts_short-sleeved-tees
# 2  /content/drive/MyDrive/Computer Vision Project...  t-shirts_short-sleeved-tees
# 3  /content/drive/MyDrive/Computer Vision Project...  t-shirts_short-sleeved-tees

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 4
# contatore file non letti 4

# %%
# attenzione che siano tutte immagini

df39.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/t-shirts_short-sleeved-tees/46574989ln_1_r.jpg'

# %%
# fine 39

# %%
# lunghezza n° elementi 
len(in_dir_list[40])
# Out:
# 150

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[40]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[40], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df40= pd.DataFrame() # nome del df
df40['image_path']= directory
df40['class']= dir[40] # valore della classe da inserire

df40
# Out:
#                                            image_path                    class
# 0   /content/drive/MyDrive/Computer Vision Project...  t-shirts_solid-t-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  t-shirts_solid-t-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  t-shirts_solid-t-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  t-shirts_solid-t-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  t-shirts_solid-t-shirts
# ..                                                ...                      ...
# 70  /content/drive/MyDrive/Computer Vision Project...  t-shirts_solid-t-shirts
# 71  /content/drive/MyDrive/Computer Vision Project...  t-shirts_solid-t-shirts
# 72  /content/drive/MyDrive/Computer Vision Project...  t-shirts_solid-t-shirts
# 73  /content/drive/MyDrive/Computer Vision Project...  t-shirts_solid-t-shirts
# 74  /content/drive/MyDrive/Computer Vision Project...  t-shirts_solid-t-shirts
#
# [75 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 75
# contatore file non letti 75

# %%
# attenzione che siano tutte immagini

df40.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/t-shirts_solid-t-shirts/22004242fq_1_r.jpg'

# %%
# fine 40

# %%
# lunghezza n° elementi 
len(in_dir_list[41])
# Out:
# 6

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[41]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[41], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df41= pd.DataFrame() # nome del df
df41['image_path']= directory
df41['class']= dir[41] # valore della classe da inserire

df41
# Out:
#                                           image_path                 class
# 0  /content/drive/MyDrive/Computer Vision Project...  t-shirts_sports-bras
# 1  /content/drive/MyDrive/Computer Vision Project...  t-shirts_sports-bras
# 2  /content/drive/MyDrive/Computer Vision Project...  t-shirts_sports-bras

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 3
# contatore file non letti 3

# %%
# attenzione che siano tutte immagini

df41.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/t-shirts_sports-bras/12202709pp_1_r.jpg'

# %%
# fine 41

# %%
# lunghezza n° elementi 
len(in_dir_list[42])
# Out:
# 2108

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[42]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[42], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df42= pd.DataFrame() # nome del df
df42['image_path']= directory
df42['class']= dir[42] # valore della classe da inserire

df42
# Out:
#                                              image_path              class
# 0     /content/drive/MyDrive/Computer Vision Project...  t-shirts_t-shirts
# 1     /content/drive/MyDrive/Computer Vision Project...  t-shirts_t-shirts
# 2     /content/drive/MyDrive/Computer Vision Project...  t-shirts_t-shirts
# 3     /content/drive/MyDrive/Computer Vision Project...  t-shirts_t-shirts
# 4     /content/drive/MyDrive/Computer Vision Project...  t-shirts_t-shirts
# ...                                                 ...                ...
# 1049  /content/drive/MyDrive/Computer Vision Project...  t-shirts_t-shirts
# 1050  /content/drive/MyDrive/Computer Vision Project...  t-shirts_t-shirts
# 1051  /content/drive/MyDrive/Computer Vision Project...  t-shirts_t-shirts
# 1052  /content/drive/MyDrive/Computer Vision Project...  t-shirts_t-shirts
# 1053  /content/drive/MyDrive/Computer Vision Project...  t-shirts_t-shirts
#
# [1054 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 1054
# contatore file non letti 1054

# %%
# attenzione che siano tutte immagini

df42.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/t-shirts_t-shirts/12027868if_1_f.jpg'

# %%
# fine 42

# %%
# lunghezza n° elementi 
len(in_dir_list[43])
# Out:
# 26

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[43]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[43], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df43= pd.DataFrame() # nome del df
df43['image_path']= directory
df43['class']= dir[43] # valore della classe da inserire

df43
# Out:
#                                            image_path               class
# 0   /content/drive/MyDrive/Computer Vision Project...  t-shirts_tank-tops
# 1   /content/drive/MyDrive/Computer Vision Project...  t-shirts_tank-tops
# 2   /content/drive/MyDrive/Computer Vision Project...  t-shirts_tank-tops
# 3   /content/drive/MyDrive/Computer Vision Project...  t-shirts_tank-tops
# 4   /content/drive/MyDrive/Computer Vision Project...  t-shirts_tank-tops
# 5   /content/drive/MyDrive/Computer Vision Project...  t-shirts_tank-tops
# 6   /content/drive/MyDrive/Computer Vision Project...  t-shirts_tank-tops
# 7   /content/drive/MyDrive/Computer Vision Project...  t-shirts_tank-tops
# 8   /content/drive/MyDrive/Computer Vision Project...  t-shirts_tank-tops
# 9   /content/drive/MyDrive/Computer Vision Project...  t-shirts_tank-tops
# 10  /content/drive/MyDrive/Computer Vision Project...  t-shirts_tank-tops
# 11  /content/drive/MyDrive/Computer Vision Project...  t-shirts_tank-tops
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df43.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/t-shirts_tank-tops/46479193cr_1_r.jpg'

# %%
# fine 43

# %%
# lunghezza n° elementi 
len(in_dir_list[44])
# Out:
# 48

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[44]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[44], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df44= pd.DataFrame() # nome del df
df44['image_path']= directory
df44['class']= dir[44] # valore della classe da inserire

df44
# Out:
#                                            image_path               class
# 0   /content/drive/MyDrive/Computer Vision Project...  t-shirts_vest-tops
# 1   /content/drive/MyDrive/Computer Vision Project...  t-shirts_vest-tops
# 2   /content/drive/MyDrive/Computer Vision Project...  t-shirts_vest-tops
# 3   /content/drive/MyDrive/Computer Vision Project...  t-shirts_vest-tops
# 4   /content/drive/MyDrive/Computer Vision Project...  t-shirts_vest-tops
# 5   /content/drive/MyDrive/Computer Vision Project...  t-shirts_vest-tops
# 6   /content/drive/MyDrive/Computer Vision Project...  t-shirts_vest-tops
# 7   /content/drive/MyDrive/Computer Vision Project...  t-shirts_vest-tops
# 8   /content/drive/MyDrive/Computer Vision Project...  t-shirts_vest-tops
# 9   /content/drive/MyDrive/Computer Vision Project...  t-shirts_vest-tops
# 10  /content/drive/MyDrive/Computer Vision Project...  t-shirts_vest-tops
# 11  /content/drive/MyDrive/Computer Vision Project...  t-shirts_vest-tops
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 24
# contatore file non letti 24

# %%
# attenzione che siano tutte immagini

df44.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/t-shirts_vest-tops/12074517aj_1_r.jpg'

# %%
# fine 44

# %%
# lunghezza n° elementi 
len(in_dir_list[45])
# Out:
# 384

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[45]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[45], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df45= pd.DataFrame() # nome del df
df45['image_path']= directory
df45['class']= dir[45] # valore della classe da inserire

df45
# Out:
#                                             image_path                   class
# 0    /content/drive/MyDrive/Computer Vision Project...  tops--tees_polo-shirts
# 1    /content/drive/MyDrive/Computer Vision Project...  tops--tees_polo-shirts
# 2    /content/drive/MyDrive/Computer Vision Project...  tops--tees_polo-shirts
# 3    /content/drive/MyDrive/Computer Vision Project...  tops--tees_polo-shirts
# 4    /content/drive/MyDrive/Computer Vision Project...  tops--tees_polo-shirts
# ..                                                 ...                     ...
# 187  /content/drive/MyDrive/Computer Vision Project...  tops--tees_polo-shirts
# 188  /content/drive/MyDrive/Computer Vision Project...  tops--tees_polo-shirts
# 189  /content/drive/MyDrive/Computer Vision Project...  tops--tees_polo-shirts
# 190  /content/drive/MyDrive/Computer Vision Project...  tops--tees_polo-shirts
# 191  /content/drive/MyDrive/Computer Vision Project...  tops--tees_polo-shirts
#
# [192 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 192
# contatore file non letti 192

# %%
# attenzione che siano tutte immagini

df45.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops--tees_polo-shirts/12002540gl_1_f.jpg'

# %%
# fine 45

# %%
# lunghezza n° elementi 
len(in_dir_list[46])
# Out:
# 1344

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[46]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[46], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df46= pd.DataFrame() # nome del df
df46['image_path']= directory
df46['class']= dir[46] # valore della classe da inserire

df46
# Out:
#                                             image_path                   class
# 0    /content/drive/MyDrive/Computer Vision Project...  tops--tees_sweatshirts
# 1    /content/drive/MyDrive/Computer Vision Project...  tops--tees_sweatshirts
# 2    /content/drive/MyDrive/Computer Vision Project...  tops--tees_sweatshirts
# 3    /content/drive/MyDrive/Computer Vision Project...  tops--tees_sweatshirts
# 4    /content/drive/MyDrive/Computer Vision Project...  tops--tees_sweatshirts
# ..                                                 ...                     ...
# 667  /content/drive/MyDrive/Computer Vision Project...  tops--tees_sweatshirts
# 668  /content/drive/MyDrive/Computer Vision Project...  tops--tees_sweatshirts
# 669  /content/drive/MyDrive/Computer Vision Project...  tops--tees_sweatshirts
# 670  /content/drive/MyDrive/Computer Vision Project...  tops--tees_sweatshirts
# 671  /content/drive/MyDrive/Computer Vision Project...  tops--tees_sweatshirts
#
# [672 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 672
# contatore file non letti 672

# %%
# attenzione che siano tutte immagini

df46.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops--tees_sweatshirts/12014860um_1_f.jpg'

# %%
# fine 46

# %%
# lunghezza n° elementi 
len(in_dir_list[47])
# Out:
# 2632

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[47]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[47], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df47= pd.DataFrame() # nome del df
df47['image_path']= directory
df47['class']= dir[47] # valore della classe da inserire

df47
# Out:
#                                              image_path                class
# 0     /content/drive/MyDrive/Computer Vision Project...  tops--tees_t-shirts
# 1     /content/drive/MyDrive/Computer Vision Project...  tops--tees_t-shirts
# 2     /content/drive/MyDrive/Computer Vision Project...  tops--tees_t-shirts
# 3     /content/drive/MyDrive/Computer Vision Project...  tops--tees_t-shirts
# 4     /content/drive/MyDrive/Computer Vision Project...  tops--tees_t-shirts
# ...                                                 ...                  ...
# 1311  /content/drive/MyDrive/Computer Vision Project...  tops--tees_t-shirts
# 1312  /content/drive/MyDrive/Computer Vision Project...  tops--tees_t-shirts
# 1313  /content/drive/MyDrive/Computer Vision Project...  tops--tees_t-shirts
# 1314  /content/drive/MyDrive/Computer Vision Project...  tops--tees_t-shirts
# 1315  /content/drive/MyDrive/Computer Vision Project...  tops--tees_t-shirts
#
# [1316 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 1316
# contatore file non letti 1316

# %%
# attenzione che siano tutte immagini

df47.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops--tees_t-shirts/11404085ls_1_f.jpg'

# %%
# fine 47

# %%
# lunghezza n° elementi 
len(in_dir_list[48])
# Out:
# 250

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[48]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[48], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df48= pd.DataFrame() # nome del df
df48['image_path']= directory
df48['class']= dir[48] # valore della classe da inserire

df48
# Out:
#                                             image_path                 class
# 0    /content/drive/MyDrive/Computer Vision Project...  tops--tees_tank-tops
# 1    /content/drive/MyDrive/Computer Vision Project...  tops--tees_tank-tops
# 2    /content/drive/MyDrive/Computer Vision Project...  tops--tees_tank-tops
# 3    /content/drive/MyDrive/Computer Vision Project...  tops--tees_tank-tops
# 4    /content/drive/MyDrive/Computer Vision Project...  tops--tees_tank-tops
# ..                                                 ...                   ...
# 120  /content/drive/MyDrive/Computer Vision Project...  tops--tees_tank-tops
# 121  /content/drive/MyDrive/Computer Vision Project...  tops--tees_tank-tops
# 122  /content/drive/MyDrive/Computer Vision Project...  tops--tees_tank-tops
# 123  /content/drive/MyDrive/Computer Vision Project...  tops--tees_tank-tops
# 124  /content/drive/MyDrive/Computer Vision Project...  tops--tees_tank-tops
#
# [125 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 125
# contatore file non letti 125

# %%
# attenzione che siano tutte immagini

df48.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops--tees_tank-tops/12015607vq_1_f.jpg'

# %%
# fine 48

# %%
# lunghezza n° elementi 
len(in_dir_list[49])
# Out:
# 2558

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[49]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[49], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df49= pd.DataFrame() # nome del df
df49['image_path']= directory
df49['class']= dir[49] # valore della classe da inserire

df49
# Out:
#                                              image_path            class
# 0     /content/drive/MyDrive/Computer Vision Project...  tops--tees_tops
# 1     /content/drive/MyDrive/Computer Vision Project...  tops--tees_tops
# 2     /content/drive/MyDrive/Computer Vision Project...  tops--tees_tops
# 3     /content/drive/MyDrive/Computer Vision Project...  tops--tees_tops
# 4     /content/drive/MyDrive/Computer Vision Project...  tops--tees_tops
# ...                                                 ...              ...
# 1274  /content/drive/MyDrive/Computer Vision Project...  tops--tees_tops
# 1275  /content/drive/MyDrive/Computer Vision Project...  tops--tees_tops
# 1276  /content/drive/MyDrive/Computer Vision Project...  tops--tees_tops
# 1277  /content/drive/MyDrive/Computer Vision Project...  tops--tees_tops
# 1278  /content/drive/MyDrive/Computer Vision Project...  tops--tees_tops
#
# [1279 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 1279
# contatore file non letti 1279

# %%
# attenzione che siano tutte immagini

df49.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops--tees_tops/12009751mw_1_f.jpg'

# %%
# fine 49

# %%
# lunghezza n° elementi 
len(in_dir_list[50])
# Out:
# 48

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[50]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[50], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df50= pd.DataFrame() # nome del df
df50['image_path']= directory
df50['class']= dir[50] # valore della classe da inserire

df50
# Out:
#                                            image_path                 class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops--tees_tube-tops
# 1   /content/drive/MyDrive/Computer Vision Project...  tops--tees_tube-tops
# 2   /content/drive/MyDrive/Computer Vision Project...  tops--tees_tube-tops
# 3   /content/drive/MyDrive/Computer Vision Project...  tops--tees_tube-tops
# 4   /content/drive/MyDrive/Computer Vision Project...  tops--tees_tube-tops
# 5   /content/drive/MyDrive/Computer Vision Project...  tops--tees_tube-tops
# 6   /content/drive/MyDrive/Computer Vision Project...  tops--tees_tube-tops
# 7   /content/drive/MyDrive/Computer Vision Project...  tops--tees_tube-tops
# 8   /content/drive/MyDrive/Computer Vision Project...  tops--tees_tube-tops
# 9   /content/drive/MyDrive/Computer Vision Project...  tops--tees_tube-tops
# 10  /content/drive/MyDrive/Computer Vision Project...  tops--tees_tube-tops
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 24
# contatore file non letti 24

# %%
# attenzione che siano tutte immagini

df50.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops--tees_tube-tops/12181467xh_1_f.jpg'

# %%
# fine 50

# %%
# lunghezza n° elementi 
len(in_dir_list[51])
# Out:
# 14

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[51]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[51], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df51= pd.DataFrame() # nome del df
df51['image_path']= directory
df51['class']= dir[51] # valore della classe da inserire

df51
# Out:
#                                           image_path                   class
# 0  /content/drive/MyDrive/Computer Vision Project...  tops_3-quarter-sleeved
# 1  /content/drive/MyDrive/Computer Vision Project...  tops_3-quarter-sleeved
# 2  /content/drive/MyDrive/Computer Vision Project...  tops_3-quarter-sleeved
# 3  /content/drive/MyDrive/Computer Vision Project...  tops_3-quarter-sleeved
# 4  /content/drive/MyDrive/Computer Vision Project...  tops_3-quarter-sleeved
# 5  /content/drive/MyDrive/Computer Vision Project...  tops_3-quarter-sleeved
# 6  /content/drive/MyDrive/Computer Vision Project...  tops_3-quarter-sleeved

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 7
# contatore file non letti 7

# %%
# attenzione che siano tutte immagini

df51.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_3-quarter-sleeved/37527644ds_1_f.jpg'

# %%
# fine 51

# %%
# lunghezza n° elementi 
len(in_dir_list[52])
# Out:
# 34

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[52]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[52], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df52= pd.DataFrame() # nome del df
df52['image_path']= directory
df52['class']= dir[52] # valore della classe da inserire

df52
# Out:
#                                            image_path         class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops_blouses
# 1   /content/drive/MyDrive/Computer Vision Project...  tops_blouses
# 2   /content/drive/MyDrive/Computer Vision Project...  tops_blouses
# 3   /content/drive/MyDrive/Computer Vision Project...  tops_blouses
# 4   /content/drive/MyDrive/Computer Vision Project...  tops_blouses
# 5   /content/drive/MyDrive/Computer Vision Project...  tops_blouses
# 6   /content/drive/MyDrive/Computer Vision Project...  tops_blouses
# 7   /content/drive/MyDrive/Computer Vision Project...  tops_blouses
# 8   /content/drive/MyDrive/Computer Vision Project...  tops_blouses
# 9   /content/drive/MyDrive/Computer Vision Project...  tops_blouses
# 10  /content/drive/MyDrive/Computer Vision Project...  tops_blouses
# 11  /content/drive/MyDrive/Computer Vision Project...  tops_blouses
# 12  /content/drive/MyDrive/Computer Vision Project...  tops_blouses
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 17
# contatore file non letti 17

# %%
# attenzione che siano tutte immagini

df52.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_blouses/12027936rp_1_f.jpg'

# %%
# fine 52

# %%
# lunghezza n° elementi 
len(in_dir_list[53])
# Out:
# 622

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[53]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[53], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df53= pd.DataFrame() # nome del df
df53['image_path']= directory
df53['class']= dir[53] # valore della classe da inserire

df53
# Out:
#                                             image_path               class
# 0    /content/drive/MyDrive/Computer Vision Project...  tops_casual-shirts
# 1    /content/drive/MyDrive/Computer Vision Project...  tops_casual-shirts
# 2    /content/drive/MyDrive/Computer Vision Project...  tops_casual-shirts
# 3    /content/drive/MyDrive/Computer Vision Project...  tops_casual-shirts
# 4    /content/drive/MyDrive/Computer Vision Project...  tops_casual-shirts
# ..                                                 ...                 ...
# 306  /content/drive/MyDrive/Computer Vision Project...  tops_casual-shirts
# 307  /content/drive/MyDrive/Computer Vision Project...  tops_casual-shirts
# 308  /content/drive/MyDrive/Computer Vision Project...  tops_casual-shirts
# 309  /content/drive/MyDrive/Computer Vision Project...  tops_casual-shirts
# 310  /content/drive/MyDrive/Computer Vision Project...  tops_casual-shirts
#
# [311 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 311
# contatore file non letti 311

# %%
# attenzione che siano tutte immagini

df53.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_casual-shirts/10516758727706807_1_in.jpg'

# %%
# fine 53

# %%
# lunghezza n° elementi 
len(in_dir_list[54])
# Out:
# 4

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[54]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[54], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df54= pd.DataFrame() # nome del df
df54['image_path']= directory
df54['class']= dir[54] # valore della classe da inserire

df54
# Out:
#                                           image_path              class
# 0  /content/drive/MyDrive/Computer Vision Project...  tops_checked-tops
# 1  /content/drive/MyDrive/Computer Vision Project...  tops_checked-tops

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 2
# contatore file non letti 2

# %%
# attenzione che siano tutte immagini

df54.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_checked-tops/46554823ss_1_r.jpg'

# %%
# fine 54

# %%
# lunghezza n° elementi 
len(in_dir_list[55])
# Out:
# 32

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[55]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[55], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df55= pd.DataFrame() # nome del df
df55['image_path']= directory
df55['class']= dir[55] # valore della classe da inserire

df55
# Out:
#                                            image_path                class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-jackets
# 1   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-jackets
# 2   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-jackets
# 3   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-jackets
# 4   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-jackets
# 5   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-jackets
# 6   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-jackets
# 7   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-jackets
# 8   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-jackets
# 9   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-jackets
# 10  /content/drive/MyDrive/Computer Vision Project...  tops_fleece-jackets
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 16
# contatore file non letti 16

# %%
# attenzione che siano tutte immagini

df55.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_fleece-jackets/34841007tf_1_r.jpg'

# %%
# fine 55

# %%
# lunghezza n° elementi 
len(in_dir_list[56])
# Out:
# 104

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[56]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[56], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df56= pd.DataFrame() # nome del df
df56['image_path']= directory
df56['class']= dir[56] # valore della classe da inserire

df56
# Out:
#                                            image_path             class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-tops
# 1   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-tops
# 2   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-tops
# 3   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-tops
# 4   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-tops
# 5   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-tops
# 6   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-tops
# 7   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-tops
# 8   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-tops
# 9   /content/drive/MyDrive/Computer Vision Project...  tops_fleece-tops
# 10  /content/drive/MyDrive/Computer Vision Project...  tops_fleece-tops
# 11  /content/drive/MyDrive/Computer Vision Project...  tops_fleece-tops
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 52
# contatore file non letti 52

# %%
# attenzione che siano tutte immagini

df56.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_fleece-tops/46554922gs_1_r.jpg'

# %%
# fine 56

# %%
# lunghezza n° elementi 
len(in_dir_list[57])
# Out:
# 10

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[57]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[57], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df57= pd.DataFrame() # nome del df
df57['image_path']= directory
df57['class']= dir[57] # valore della classe da inserire

df57
# Out:
#                                           image_path             class
# 0  /content/drive/MyDrive/Computer Vision Project...  tops_jersey-tops
# 1  /content/drive/MyDrive/Computer Vision Project...  tops_jersey-tops
# 2  /content/drive/MyDrive/Computer Vision Project...  tops_jersey-tops
# 3  /content/drive/MyDrive/Computer Vision Project...  tops_jersey-tops
# 4  /content/drive/MyDrive/Computer Vision Project...  tops_jersey-tops

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 5
# contatore file non letti 5

# %%
# attenzione che siano tutte immagini

df57.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_jersey-tops/46608617xh_1_r.jpg'

# %%
# fine 57

# %%
# lunghezza n° elementi 
len(in_dir_list[58])
# Out:
# 1858

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[58]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[58], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df58= pd.DataFrame() # nome del df
df58['image_path']= directory
df58['class']= dir[58] # valore della classe da inserire

df58
# Out:
#                                             image_path          class
# 0    /content/drive/MyDrive/Computer Vision Project...  tops_knitwear
# 1    /content/drive/MyDrive/Computer Vision Project...  tops_knitwear
# 2    /content/drive/MyDrive/Computer Vision Project...  tops_knitwear
# 3    /content/drive/MyDrive/Computer Vision Project...  tops_knitwear
# 4    /content/drive/MyDrive/Computer Vision Project...  tops_knitwear
# ..                                                 ...            ...
# 924  /content/drive/MyDrive/Computer Vision Project...  tops_knitwear
# 925  /content/drive/MyDrive/Computer Vision Project...  tops_knitwear
# 926  /content/drive/MyDrive/Computer Vision Project...  tops_knitwear
# 927  /content/drive/MyDrive/Computer Vision Project...  tops_knitwear
# 928  /content/drive/MyDrive/Computer Vision Project...  tops_knitwear
#
# [929 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 929
# contatore file non letti 929

# %%
# attenzione che siano tutte immagini

df58.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_knitwear/1009780_1_in.jpg'

# %%
# fine 58

# %%
# lunghezza n° elementi 
len(in_dir_list[59])
# Out:
# 12

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[59]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[59], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df59= pd.DataFrame() # nome del df
df59['image_path']= directory
df59['class']= dir[59] # valore della classe da inserire

df59
# Out:
#                                           image_path                    class
# 0  /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-shirts
# 1  /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-shirts
# 2  /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-shirts
# 3  /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-shirts
# 4  /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-shirts
# 5  /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-shirts

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df59.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_long-sleeve-shirts/37196581in_1_f.jpg'

# %%
# fine 59

# %%
# lunghezza n° elementi 
len(in_dir_list[60])
# Out:
# 28

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[60]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[60], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df60= pd.DataFrame() # nome del df
df60['image_path']= directory
df60['class']= dir[60] # valore della classe da inserire

df60
# Out:
#                                            image_path                      class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-t-shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-t-shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-t-shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-t-shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-t-shirts
# 5   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-t-shirts
# 6   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-t-shirts
# 7   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-t-shirts
# 8   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-t-shirts
# 9   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-t-shirts
# 10  /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeve-t-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 14
# contatore file non letti 14

# %%
# attenzione che siano tutte immagini

df60.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_long-sleeve-t-shirts/12068377pc_1_f.jpg'

# %%
# fine 60

# %%
# lunghezza n° elementi 
len(in_dir_list[61])
# Out:
# 74

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[61]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[61], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df61= pd.DataFrame() # nome del df
df61['image_path']= directory
df61['class']= dir[61] # valore della classe da inserire

df61
# Out:
#                                            image_path              class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeved
# 1   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeved
# 2   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeved
# 3   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeved
# 4   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeved
# 5   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeved
# 6   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeved
# 7   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeved
# 8   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeved
# 9   /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeved
# 10  /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeved
# 11  /content/drive/MyDrive/Computer Vision Project...  tops_long-sleeved
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 37
# contatore file non letti 37

# %%
# attenzione che siano tutte immagini

df61.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_long-sleeved/12104336go_1_f.jpg'

# %%
# fine 61

# %%
# lunghezza n° elementi 
len(in_dir_list[62])
# Out:
# 10

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[62]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[62], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df62= pd.DataFrame() # nome del df
df62['image_path']= directory
df62['class']= dir[62] # valore della classe da inserire

df62
# Out:
#                                           image_path              class
# 0  /content/drive/MyDrive/Computer Vision Project...  tops_ls-knit-tops
# 1  /content/drive/MyDrive/Computer Vision Project...  tops_ls-knit-tops
# 2  /content/drive/MyDrive/Computer Vision Project...  tops_ls-knit-tops
# 3  /content/drive/MyDrive/Computer Vision Project...  tops_ls-knit-tops
# 4  /content/drive/MyDrive/Computer Vision Project...  tops_ls-knit-tops

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df62.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_ls-knit-tops/46572928xf_1_r.jpg'

# %%
# fine 62

# %%
# lunghezza n° elementi 
len(in_dir_list[63])
# Out:
# 4

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[63]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[63], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df63= pd.DataFrame() # nome del df
df63['image_path']= directory
df63['class']= dir[63] # valore della classe da inserire

df63
# Out:
#                                           image_path              class
# 0  /content/drive/MyDrive/Computer Vision Project...  tops_one-shoulder
# 1  /content/drive/MyDrive/Computer Vision Project...  tops_one-shoulder

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df63.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_one-shoulder/37787859jv_1_f.jpg'

# %%
# fine 63

# %%
# lunghezza n° elementi 
len(in_dir_list[64])
# Out:
# 378

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[64]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[64], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df64= pd.DataFrame() # nome del df
df64['image_path']= directory
df64['class']= dir[64] # valore della classe da inserire

df64
# Out:
#                                             image_path             class
# 0    /content/drive/MyDrive/Computer Vision Project...  tops_polo-shirts
# 1    /content/drive/MyDrive/Computer Vision Project...  tops_polo-shirts
# 2    /content/drive/MyDrive/Computer Vision Project...  tops_polo-shirts
# 3    /content/drive/MyDrive/Computer Vision Project...  tops_polo-shirts
# 4    /content/drive/MyDrive/Computer Vision Project...  tops_polo-shirts
# ..                                                 ...               ...
# 184  /content/drive/MyDrive/Computer Vision Project...  tops_polo-shirts
# 185  /content/drive/MyDrive/Computer Vision Project...  tops_polo-shirts
# 186  /content/drive/MyDrive/Computer Vision Project...  tops_polo-shirts
# 187  /content/drive/MyDrive/Computer Vision Project...  tops_polo-shirts
# 188  /content/drive/MyDrive/Computer Vision Project...  tops_polo-shirts
#
# [189 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 189
# contatore file non letti 189

# %%
# attenzione che siano tutte immagini

df64.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_polo-shirts/10516758727706810_1_in.jpg'

# %%
# fine 64

# %%
# lunghezza n° elementi 
len(in_dir_list[65])
# Out:
# 22

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[65]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[65], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df65= pd.DataFrame() # nome del df
df65['image_path']= directory
df65['class']= dir[65] # valore della classe da inserire

df65
# Out:
#                                            image_path              class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops_printed-tops
# 1   /content/drive/MyDrive/Computer Vision Project...  tops_printed-tops
# 2   /content/drive/MyDrive/Computer Vision Project...  tops_printed-tops
# 3   /content/drive/MyDrive/Computer Vision Project...  tops_printed-tops
# 4   /content/drive/MyDrive/Computer Vision Project...  tops_printed-tops
# 5   /content/drive/MyDrive/Computer Vision Project...  tops_printed-tops
# 6   /content/drive/MyDrive/Computer Vision Project...  tops_printed-tops
# 7   /content/drive/MyDrive/Computer Vision Project...  tops_printed-tops
# 8   /content/drive/MyDrive/Computer Vision Project...  tops_printed-tops
# 9   /content/drive/MyDrive/Computer Vision Project...  tops_printed-tops
# 10  /content/drive/MyDrive/Computer Vision Project...  tops_printed-tops

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df65.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_printed-tops/46574876ni_1_r.jpg'

# %%
# fine 65

# %%
# lunghezza n° elementi 
len(in_dir_list[66])
# Out:
# 194

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[66]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[66], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df66= pd.DataFrame() # nome del df
df66['image_path']= directory
df66['class']= dir[66] # valore della classe da inserire

df66
# Out:
#                                            image_path        class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops_shirts
# 1   /content/drive/MyDrive/Computer Vision Project...  tops_shirts
# 2   /content/drive/MyDrive/Computer Vision Project...  tops_shirts
# 3   /content/drive/MyDrive/Computer Vision Project...  tops_shirts
# 4   /content/drive/MyDrive/Computer Vision Project...  tops_shirts
# ..                                                ...          ...
# 92  /content/drive/MyDrive/Computer Vision Project...  tops_shirts
# 93  /content/drive/MyDrive/Computer Vision Project...  tops_shirts
# 94  /content/drive/MyDrive/Computer Vision Project...  tops_shirts
# 95  /content/drive/MyDrive/Computer Vision Project...  tops_shirts
# 96  /content/drive/MyDrive/Computer Vision Project...  tops_shirts
#
# [97 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 97
# contatore file non letti 97

# %%
# attenzione che siano tutte immagini

df66.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_shirts/12027796hk_1_f.jpg'

# %%
# fine 66

# %%
# lunghezza n° elementi 
len(in_dir_list[67])
# Out:
# 8

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[67]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[67], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df67= pd.DataFrame() # nome del df
df67['image_path']= directory
df67['class']= dir[67] # valore della classe da inserire

df67
# Out:
#                                           image_path                     class
# 0  /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeve-shirts
# 1  /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeve-shirts
# 2  /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeve-shirts
# 3  /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeve-shirts

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df67.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_short-sleeve-shirts/37200293cn_1_f.jpg'

# %%
# fine 67

# %%
# lunghezza n° elementi 
len(in_dir_list[68])
# Out:
# 256

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[68]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[68], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df68= pd.DataFrame() # nome del df
df68['image_path']= directory
df68['class']= dir[68] # valore della classe da inserire

df68
# Out:
#                                             image_path                       class
# 0    /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeve-t-shirts
# 1    /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeve-t-shirts
# 2    /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeve-t-shirts
# 3    /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeve-t-shirts
# 4    /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeve-t-shirts
# ..                                                 ...                         ...
# 123  /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeve-t-shirts
# 124  /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeve-t-shirts
# 125  /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeve-t-shirts
# 126  /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeve-t-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 128
# contatore file non letti 128

# %%
# attenzione che siano tutte immagini

df68.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_short-sleeve-t-shirts/12001690fq_1_f.jpg'

# %%
# fine 68

# %%
# lunghezza n° elementi 
len(in_dir_list[69])
# Out:
# 98

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[69]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[69], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df69= pd.DataFrame() # nome del df
df69['image_path']= directory
df69['class']= dir[69] # valore della classe da inserire

df69
# Out:
#                                            image_path               class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeved
# 1   /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeved
# 2   /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeved
# 3   /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeved
# 4   /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeved
# 5   /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeved
# 6   /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeved
# 7   /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeved
# 8   /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeved
# 9   /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeved
# 10  /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeved
# 11  /content/drive/MyDrive/Computer Vision Project...  tops_short-sleeved
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 44
# contatore file non letti 54

# %%
# attenzione che siano tutte immagini

df69.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_short-sleeved/12033926om_1_f.jpg'

# %%
# fine 69

# %%
# lunghezza n° elementi 
len(in_dir_list[70])
# Out:
# 134

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[70]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[70], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df70= pd.DataFrame() # nome del df
df70['image_path']= directory
df70['class']= dir[70] # valore della classe da inserire

df70
# Out:
#                                            image_path              class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops_sl-knit-tops
# 1   /content/drive/MyDrive/Computer Vision Project...  tops_sl-knit-tops
# 2   /content/drive/MyDrive/Computer Vision Project...  tops_sl-knit-tops
# 3   /content/drive/MyDrive/Computer Vision Project...  tops_sl-knit-tops
# 4   /content/drive/MyDrive/Computer Vision Project...  tops_sl-knit-tops
# ..                                                ...                ...
# 62  /content/drive/MyDrive/Computer Vision Project...  tops_sl-knit-tops
# 63  /content/drive/MyDrive/Computer Vision Project...  tops_sl-knit-tops
# 64  /content/drive/MyDrive/Computer Vision Project...  tops_sl-knit-tops
# 65  /content/drive/MyDrive/Computer Vision Project...  tops_sl-knit-tops
# 66  /content/drive/MyDrive/Computer Vision Project...  tops_sl-knit-tops
#
# [67 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 67
# contatore file non letti 67

# %%
# attenzione che siano tutte immagini

df70.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_sl-knit-tops/34831522sp_1_r.jpg'

# %%
# fine 70

# %%
# lunghezza n° elementi 
len(in_dir_list[71])
# Out:
# 84

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[71]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[71], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df71= pd.DataFrame() # nome del df
df71['image_path']= directory
df71['class']= dir[71] # valore della classe da inserire

df71
# Out:
#                                            image_path            class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless
# 1   /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless
# 2   /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless
# 3   /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless
# 4   /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless
# 5   /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless
# 6   /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless
# 7   /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless
# 8   /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless
# 9   /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless
# 10  /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless
# 11  /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 42
# contatore file non letti 42

# %%
# attenzione che siano tutte immagini

df71.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_sleeveless/37529939cw_1_f.jpg'

# %%
# fine 71

# %%
# lunghezza n° elementi 
len(in_dir_list[72])
# Out:
# 6

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[72]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[72], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df72= pd.DataFrame() # nome del df
df72['image_path']= directory
df72['class']= dir[72] # valore della classe da inserire

df72
# Out:
#                                           image_path                     class
# 0  /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless-t-shirts
# 1  /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless-t-shirts
# 2  /content/drive/MyDrive/Computer Vision Project...  tops_sleeveless-t-shirts

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df72.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_sleeveless-t-shirts/37204516jb_1_f.jpg'

# %%
# fine 72

# %%
# lunghezza n° elementi 
len(in_dir_list[73])
# Out:
# 80

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[73]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[73], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df73= pd.DataFrame() # nome del df
df73['image_path']= directory
df73['class']= dir[73] # valore della classe da inserire

df73
# Out:
#                                            image_path            class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops_solid-tops
# 1   /content/drive/MyDrive/Computer Vision Project...  tops_solid-tops
# 2   /content/drive/MyDrive/Computer Vision Project...  tops_solid-tops
# 3   /content/drive/MyDrive/Computer Vision Project...  tops_solid-tops
# 4   /content/drive/MyDrive/Computer Vision Project...  tops_solid-tops
# 5   /content/drive/MyDrive/Computer Vision Project...  tops_solid-tops
# 6   /content/drive/MyDrive/Computer Vision Project...  tops_solid-tops
# 7   /content/drive/MyDrive/Computer Vision Project...  tops_solid-tops
# 8   /content/drive/MyDrive/Computer Vision Project...  tops_solid-tops
# 9   /content/drive/MyDrive/Computer Vision Project...  tops_solid-tops
# 10  /content/drive/MyDrive/Computer Vision Project...  tops_solid-tops
# 11  /content/drive/MyDrive/Computer Vision Project...  tops_solid-tops
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 40
# contatore file non letti 40

# %%
# attenzione che siano tutte immagini

df73.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_solid-tops/46575845fm_1_r.jpg'

# %%
# fine 73

# %%
# lunghezza n° elementi 
len(in_dir_list[74])
# Out:
# 22

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[74]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[74], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df74= pd.DataFrame() # nome del df
df74['image_path']= directory
df74['class']= dir[74] # valore della classe da inserire

df74
# Out:
#                                            image_path              class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops_ss-knit-tops
# 1   /content/drive/MyDrive/Computer Vision Project...  tops_ss-knit-tops
# 2   /content/drive/MyDrive/Computer Vision Project...  tops_ss-knit-tops
# 3   /content/drive/MyDrive/Computer Vision Project...  tops_ss-knit-tops
# 4   /content/drive/MyDrive/Computer Vision Project...  tops_ss-knit-tops
# 5   /content/drive/MyDrive/Computer Vision Project...  tops_ss-knit-tops
# 6   /content/drive/MyDrive/Computer Vision Project...  tops_ss-knit-tops
# 7   /content/drive/MyDrive/Computer Vision Project...  tops_ss-knit-tops
# 8   /content/drive/MyDrive/Computer Vision Project...  tops_ss-knit-tops
# 9   /content/drive/MyDrive/Computer Vision Project...  tops_ss-knit-tops
# 10  /content/drive/MyDrive/Computer Vision Project...  tops_ss-knit-tops

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df74.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_ss-knit-tops/46557083fi_1_r.jpg'

# %%
# fine 74

# %%
# lunghezza n° elementi 
len(in_dir_list[75])
# Out:
# 44

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[75]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[75], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df75= pd.DataFrame() # nome del df
df75['image_path']= directory
df75['class']= dir[75] # valore della classe da inserire

df75
# Out:
#                                            image_path           class
# 0   /content/drive/MyDrive/Computer Vision Project...  tops_strapless
# 1   /content/drive/MyDrive/Computer Vision Project...  tops_strapless
# 2   /content/drive/MyDrive/Computer Vision Project...  tops_strapless
# 3   /content/drive/MyDrive/Computer Vision Project...  tops_strapless
# 4   /content/drive/MyDrive/Computer Vision Project...  tops_strapless
# 5   /content/drive/MyDrive/Computer Vision Project...  tops_strapless
# 6   /content/drive/MyDrive/Computer Vision Project...  tops_strapless
# 7   /content/drive/MyDrive/Computer Vision Project...  tops_strapless
# 8   /content/drive/MyDrive/Computer Vision Project...  tops_strapless
# 9   /content/drive/MyDrive/Computer Vision Project...  tops_strapless
# 10  /content/drive/MyDrive/Computer Vision Project...  tops_strapless
# 11  /content/drive/MyDrive/Computer Vision Project...  tops_strapless
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 22
# contatore file non letti 22

# %%
# attenzione che siano tutte immagini

df75.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_strapless/34540399jl_1_f.jpg'

# %%
# fine 75

# %%
# lunghezza n° elementi 
len(in_dir_list[76])
# Out:
# 14

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[76]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[76], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df76= pd.DataFrame() # nome del df
df76['image_path']= directory
df76['class']= dir[76] # valore della classe da inserire

df76
# Out:
#                                           image_path              class
# 0  /content/drive/MyDrive/Computer Vision Project...  tops_striped-tops
# 1  /content/drive/MyDrive/Computer Vision Project...  tops_striped-tops
# 2  /content/drive/MyDrive/Computer Vision Project...  tops_striped-tops
# 3  /content/drive/MyDrive/Computer Vision Project...  tops_striped-tops
# 4  /content/drive/MyDrive/Computer Vision Project...  tops_striped-tops
# 5  /content/drive/MyDrive/Computer Vision Project...  tops_striped-tops
# 6  /content/drive/MyDrive/Computer Vision Project...  tops_striped-tops

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df76.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_striped-tops/46557092gp_1_r.jpg'

# %%
# fine 76

# %%
# lunghezza n° elementi 
len(in_dir_list[77])
# Out:
# 876

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[77]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[77], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df77= pd.DataFrame() # nome del df
df77['image_path']= directory
df77['class']= dir[77] # valore della classe da inserire

df77
# Out:
#                                             image_path          class
# 0    /content/drive/MyDrive/Computer Vision Project...  tops_t-shirts
# 1    /content/drive/MyDrive/Computer Vision Project...  tops_t-shirts
# 2    /content/drive/MyDrive/Computer Vision Project...  tops_t-shirts
# 3    /content/drive/MyDrive/Computer Vision Project...  tops_t-shirts
# 4    /content/drive/MyDrive/Computer Vision Project...  tops_t-shirts
# ..                                                 ...            ...
# 433  /content/drive/MyDrive/Computer Vision Project...  tops_t-shirts
# 434  /content/drive/MyDrive/Computer Vision Project...  tops_t-shirts
# 435  /content/drive/MyDrive/Computer Vision Project...  tops_t-shirts
# 436  /content/drive/MyDrive/Computer Vision Project...  tops_t-shirts
# 437  /content/drive/MyDrive/Computer Vision Project...  tops_t-shirts
#
# [438 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 438
# contatore file non letti 438

# %%
# attenzione che siano tutte immagini

df77.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_t-shirts/10516758727645780_1_in.jpg'

# %%
# fine 77

# %%
# lunghezza n° elementi 
len(in_dir_list[78])
# Out:
# 4248

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[78]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[78], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df78= pd.DataFrame() # nome del df
df78['image_path']= directory
df78['class']= dir[78] # valore della classe da inserire

df78
# Out:
#                                              image_path      class
# 0     /content/drive/MyDrive/Computer Vision Project...  tops_tops
# 1     /content/drive/MyDrive/Computer Vision Project...  tops_tops
# 2     /content/drive/MyDrive/Computer Vision Project...  tops_tops
# 3     /content/drive/MyDrive/Computer Vision Project...  tops_tops
# 4     /content/drive/MyDrive/Computer Vision Project...  tops_tops
# ...                                                 ...        ...
# 2119  /content/drive/MyDrive/Computer Vision Project...  tops_tops
# 2120  /content/drive/MyDrive/Computer Vision Project...  tops_tops
# 2121  /content/drive/MyDrive/Computer Vision Project...  tops_tops
# 2122  /content/drive/MyDrive/Computer Vision Project...  tops_tops
# 2123  /content/drive/MyDrive/Computer Vision Project...  tops_tops
#
# [2124 rows x 2 columns]

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 2124
# contatore file non letti 2124

# %%
# attenzione che siano tutte immagini

df78.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tops_tops/1001001_1_in.jpg'

# %%
# fine 78

# %%
# lunghezza n° elementi 
len(in_dir_list[79])
# Out:
# 20

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[79]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[79], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df79= pd.DataFrame() # nome del df
df79['image_path']= directory
df79['class']= dir[79] # valore della classe da inserire

df79
# Out:
#                                           image_path                class
# 0  /content/drive/MyDrive/Computer Vision Project...  topwear_polo-shirts
# 1  /content/drive/MyDrive/Computer Vision Project...  topwear_polo-shirts
# 2  /content/drive/MyDrive/Computer Vision Project...  topwear_polo-shirts
# 3  /content/drive/MyDrive/Computer Vision Project...  topwear_polo-shirts
# 4  /content/drive/MyDrive/Computer Vision Project...  topwear_polo-shirts
# 5  /content/drive/MyDrive/Computer Vision Project...  topwear_polo-shirts
# 6  /content/drive/MyDrive/Computer Vision Project...  topwear_polo-shirts
# 7  /content/drive/MyDrive/Computer Vision Project...  topwear_polo-shirts
# 8  /content/drive/MyDrive/Computer Vision Project...  topwear_polo-shirts
# 9  /content/drive/MyDrive/Computer Vision Project...  topwear_polo-shirts

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df79.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/topwear_polo-shirts/12332741ob_1_f.jpg'

# %%
# fine 79

# %%
# lunghezza n° elementi 
len(in_dir_list[80])
# Out:
# 36

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[80]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[80], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df80= pd.DataFrame() # nome del df
df80['image_path']= directory
df80['class']= dir[80] # valore della classe da inserire

df80
# Out:
#                                            image_path                          class
# 0   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_polos
# 1   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_polos
# 2   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_polos
# 3   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_polos
# 4   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_polos
# 5   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_polos
# 6   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_polos
# 7   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_polos
# 8   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_polos
# 9   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_polos
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 62
# contatore file non letti 62

# %%
# attenzione che siano tutte immagini

df80.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tshirts-and-sweatshirts_polos/12027642hs_1_f.jpg'

# %%
# fine 80

# %%
# lunghezza n° elementi 
len(in_dir_list[81])
# Out:
# 144

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[81]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[81], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df81= pd.DataFrame() # nome del df
df81['image_path']= directory
df81['class']= dir[81] # valore della classe da inserire

df81
# Out:
#                                            image_path                                class
# 0   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_sweatshirts
# 1   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_sweatshirts
# 2   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_sweatshirts
# 3   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_sweatshirts
# 4   /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_sweatshirts
# ..                                                ...                                  ...
# 67  /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_sweatshirts
# 68  /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_sweatshirts
# 69  /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_sweatshirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 72
# contatore file non letti 72

# %%
# attenzione che siano tutte immagini

df81.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tshirts-and-sweatshirts_sweatshirts/12004054xr_1_f.jpg'

# %%
# fine 81

# %%
# lunghezza n° elementi 
len(in_dir_list[82])
# Out:
# 286

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[82]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[82], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df82= pd.DataFrame() # nome del df
df82['image_path']= directory
df82['class']= dir[82] # valore della classe da inserire

df82
# Out:
#                                             image_path                                         class
# 0    /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirt--sweatshirts
# 1    /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirt--sweatshirts
# 2    /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirt--sweatshirts
# 3    /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirt--sweatshirts
# 4    /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirt--sweatshirts
# ..                                                 ...                                           ...
# 138  /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirt--sweatshirts
# 139  /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirt--sweatshirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 143
# contatore file non letti 143

# %%
# attenzione che siano tutte immagini

df82.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tshirts-and-sweatshirts_t-shirt--sweatshirts/12113417qu_1_f.jpg'

# %%
# fine 82

# %%
# lunghezza n° elementi 
len(in_dir_list[83])
# Out:
# 332

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'
c=0; v=0
file_save_images=[]

for i in (in_dir_list[83]): # dentro a quale directory guardare
  if i.endswith(fine_file1):
    v= v+1
    file_save_images.append(i)
       
  elif i.endswith(fine_file2):
    #print(i)
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file3):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file4):
    file_save_images.append(i)
    v= v+1

  elif i.endswith(fine_file5):
    file_save_images.append(i)
    v= v+1

  else:
    c=c+1

directory= []
for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir[83], file_save_images[i])) # in_dir: inizio del percorso verso l'immagine



df83= pd.DataFrame() # nome del df
df83['image_path']= directory
df83['class']= dir[83] # valore della classe da inserire

df83
# Out:
#                                             image_path                             class
# 0    /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirts
# 1    /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirts
# 2    /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirts
# 3    /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirts
# 4    /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirts
# ..                                                 ...                               ...
# 161  /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirts
# 162  /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirts
# 163  /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirts
# ...

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 166
# contatore file non letti 166

# %%
# attenzione che siano tutte immagini

df83.image_path[0]
# Out:
# '/content/drive/MyDrive/Computer Vision Project/Code/Dataset/Yoox/upper_body/images/tshirts-and-sweatshirts_t-shirts/11439223mu_1_f.jpg'

# %%
# fine 83

# %% [markdown]
# Unione dei vari dataset

# %%
# fino ad 84
list_df=[df0, df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20,
         df21, df22, df23, df24, df25, df26, df27, df28, df29, df30, df31, df32, df33, df34, df35, df36, df37, df38, df39, df40,
         df41, df42, df43, df44, df45, df46, df47, df48, df49, df50, df51, df52, df53, df54, df55, df56, df57, df58, df59, df60,
         df61, df62, df63, df64, df65, df66, df67, df68, df69, df70, df71, df72, df73, df74, df75, df76, df77, df78, df79, df80,
         df81, df82, df83]

len(list_df)
# Out:
# 84

# %%
# list_df
df_tot= pd.concat(list_df).reset_index()
df_tot.drop(columns='index', inplace=True)
df_tot
# Out:
#                                               image_path                             class
# 0      /content/drive/MyDrive/Computer Vision Project...                denim_denim-shirts
# 1      /content/drive/MyDrive/Computer Vision Project...                denim_denim-shirts
# 2      /content/drive/MyDrive/Computer Vision Project...                denim_denim-shirts
# 3      /content/drive/MyDrive/Computer Vision Project...                denim_denim-shirts
# 4      /content/drive/MyDrive/Computer Vision Project...                denim_denim-shirts
# ...                                                  ...                               ...
# 15362  /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirts
# 15363  /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirts
# 15364  /content/drive/MyDrive/Computer Vision Project...  tshirts-and-sweatshirts_t-shirts
# ...

# %%
assicuro= df_tot
assicuro.shape
# Out:
# (15367, 2)

# %%
assicuro.to_csv('backup.csv', index=False)

# %% [markdown]
# Trasformo class in valori

# %%
le= LabelEncoder()
le.fit(df_tot['class'])
print('Corrispondenza delle classi in ordine con i valori:\n', le.classes_)
# Out:
# Corrispondenza delle classi in ordine con i valori:
#  ['denim_denim-shirts' 'knitwear_knitted-polo-shirts'
#  'knitwear_knitted-tops' 'knitwear_track-tops' 'leather_leather-tops'
#  'polo-shirts_long-sleeves-polos' 'polo-shirts_short-sleeves-polos'
#  'shirts-and-tops_knit-sweater' 'shirts-and-tops_knitwear-shirts-and-tops'
#  'shirts-and-tops_shirts-and-blouses' 'shirts-and-tops_tops'
#  'shirts_blouses' 'shirts_casual-shirts' 'shirts_checked-shirts'
#  'shirts_classic-shirts' 'shirts_denim-shirts' 'shirts_formal-shirts'
#  'shirts_kaftans' 'shirts_long-sleeve-shirts' 'shirts_long-sleeved-shirts'
#  'shirts_men-shirts' 'shirts_plain-shirts' 'shirts_printed-shirts'
#  'shirts_shirts' 'shirts_short-sleeve-shirts'
#  'shirts_short-sleeved-shirts' 'shirts_sl-woven-tops'
#  'shirts_sleeveless-shirts' 'shirts_ss-woven-tops' 'shirts_striped-shirts'
#  'shirts_tops' 'shirts_tunics' 't-shirts_active-tops'
#  't-shirts_graphic-t-shirts' 't-shirts_logo-t-shirts'
# ...

# %%
df_tot['class']= le.transform(df_tot['class'])
df_tot
# Out:
#                                               image_path  class
# 0      /content/drive/MyDrive/Computer Vision Project...      0
# 1      /content/drive/MyDrive/Computer Vision Project...      0
# 2      /content/drive/MyDrive/Computer Vision Project...      0
# 3      /content/drive/MyDrive/Computer Vision Project...      0
# 4      /content/drive/MyDrive/Computer Vision Project...      0
# ...                                                  ...    ...
# 15362  /content/drive/MyDrive/Computer Vision Project...     83
# 15363  /content/drive/MyDrive/Computer Vision Project...     83
# 15364  /content/drive/MyDrive/Computer Vision Project...     83
# 15365  /content/drive/MyDrive/Computer Vision Project...     83
# 15366  /content/drive/MyDrive/Computer Vision Project...     83
#
# [15367 rows x 2 columns]

# %%
# scrivo il file, da scaricare per poterlo poi utilizzare
df_tot.to_csv('dati-triplet.csv', index=False)

# %%
# path giusto
df= pd.read_csv('/content/dati-triplet.csv')
df
# Out:
#                                               image_path  class
# 0      /content/drive/MyDrive/Computer Vision Project...      0
# 1      /content/drive/MyDrive/Computer Vision Project...      0
# 2      /content/drive/MyDrive/Computer Vision Project...      0
# 3      /content/drive/MyDrive/Computer Vision Project...      0
# 4      /content/drive/MyDrive/Computer Vision Project...      0
# ...                                                  ...    ...
# 15362  /content/drive/MyDrive/Computer Vision Project...     83
# 15363  /content/drive/MyDrive/Computer Vision Project...     83
# 15364  /content/drive/MyDrive/Computer Vision Project...     83
# 15365  /content/drive/MyDrive/Computer Vision Project...     83
# 15366  /content/drive/MyDrive/Computer Vision Project...     83
#
# [15367 rows x 2 columns]

# %% [markdown]
# # FINE !!!

# %%
(in_dir_list[1]) # lista delle varie immagini
# Out:
# ['39939482qw_0_d.jpg',
#  '39939482qw_1_r.jpg',
#  '39939604me_0_d.jpg',
#  '39939604me_1_r.jpg',
#  '46589216cg_0_d.jpg',
#  '46589216cg_1_r.jpg']

# %%
fine_file1= '1_r.jpg' #* .
fine_file2= '1_e.jpg'
fine_file3= '1_d.jpg'
fine_file4= '1_f.jpg'
fine_file5= '1_in.jpg'

# %%
# file su cui fare le tabelle csv
files= dict()

# %%
c=0; v=0
file_save_images=[]
indice= []

#df1= pd.DataFrame()

for j in range(len(in_dir)):
  for idx,i in enumerate(in_dir_list[j]): #j
    if i.endswith(fine_file1):
      file_save_images.append(i)
      #print(i)
      indice.append(idx)
      v= v+1
          
    elif i.endswith(fine_file2):
      #print(i)
      file_save_images.append(i)
      indice.append(idx)
      v= v+1

    elif i.endswith(fine_file3):
      file_save_images.append(i)
      indice.append(idx)
      v= v+1
      #print(i)

    elif i.endswith(fine_file4):
      file_save_images.append(i)
      indice.append(idx)
      v= v+1
      #print(i)
    
    elif i.endswith(fine_file5):
      file_save_images.append(i)
      indice.append(idx)
      v= v+1
      #print(i)

    else:
      c=c+1
  # salvi 
  files[j]= [file_save_images]
  file_save_images=[]

# %%
file_save_images
# Out:
# 11453

# %%
print('contatore file letti', v)
print('contatore file non letti', c)
# Out:
# contatore file letti 15367
# contatore file non letti 15377

# %%
files['class']=[dir]
# lettura dei dati
files['class'][0][:]
files[1][0][0]
# Out:
# '39939482qw_1_r.jpg'

# %%
files
# da scaricare il dizionario

import json
with open('dictionary.json', 'w') as f:
  json.dump(files, f)

# %%
# parte di lettura
with open('dictionary.json') as f:
  data = json.load(f)
data #

# %%
df1= pd.DataFrame()
directory= []

for i in range(len(file_save_images)):  
  directory.append(os.path.join(in_dir, file_save_images[i]))
# attenzione che siano tutte immagini
df1['image_path']= directory
df1['class']= dir[0]

df1

# %% [markdown]
# Tabella dalla lettura del file json!

# %%
prova= pd.read_json('dictionary.json')
prova

# %%
vu=[]
for i in range(len(prova['0'][0])):
  vu.append(prova['0'][0][i])
df_p= pd.DataFrame()
df_p['image_path']= vu
df_p['class']= prova['class'][0][0]
df_p
# Out:
#             image_path               class
# 0   12141279ui_1_f.jpg  denim_denim-shirts
# 1   12148956eo_1_f.jpg  denim_denim-shirts
# 2   12176911ut_1_f.jpg  denim_denim-shirts
# 3   12248250ov_1_f.jpg  denim_denim-shirts
# 4   38814303li_1_f.jpg  denim_denim-shirts
# ..                 ...                 ...
# 57  42768420ff_1_f.jpg  denim_denim-shirts
# 58  42776625sg_1_f.jpg  denim_denim-shirts
# 59  42778725lj_1_f.jpg  denim_denim-shirts
# 60  42779181hu_1_f.jpg  denim_denim-shirts
# 61  49531963he_1_f.jpg  denim_denim-shirts
#
# [62 rows x 2 columns]

# %%
count_1=0
# in_dir= np.zeros()
for lis in range(len(dir)):
  in_dir[lis]= os.path.join(path2, dir[lis]+'/') # dir di ogni classe
  #print(in_dir)
  in_dir_list[lis]= sorted(os.listdir(in_dir[lis])) # percorso immagini (di ogni classe)
  count_1 += len(in_dir_list[lis])
  #print((in_dir_list))

  df[lis]= pd.DataFrame()
  directory= []
  for i in range(len(in_dir_list[lis])):
    directory.append(os.path.join(in_dir[lis], in_dir_list[lis][i]))
  df[lis]['image_path']= directory
  df[lis]['class']= dir[lis]

df
